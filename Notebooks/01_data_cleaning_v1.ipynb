# %% [markdown]
# # Dirty IMDb Top 1000 Movies Data Cleaning V1
# **Datasets :** [Dirty_imdb_top_1000.csv](../Datasets/Dirty_imdb_top_1000.csv)
#
# **Author   :** Fajar Laksono
#
# **Github   :** http://fajarlaksono.github.io/

# %% [markdown]
# ## 1. Overview
#
# This project focuses on the understanding and preparing the data sets of **Dirty IMDb Top 1000 Movies** (`Dirty_imdb_top_1000.csv`), Which is provided in a "dirty" or an unclear format. The dataset contains multiple issues such as missing required columns, incomplete values, and inconsistent formating that prevent us to have futher of extracting any insight from the data set.
#
# ## 2. Objectives
# The primarly objective of this project is to identify and clean the issues in order to produce a more reliable dataset that can serve aas a foundation for meaningful analysis.
#
# Key steps in this project will include:
# - Identifying data quality issues.
# - Retriving the column country.
# - Cleaning and resolving the issues.
# - Producing a cleaned version of the dataset.
#
# The dataset contains 1,000 movies from various countries. As part of the insight extraction process, it is required for us to recover the missing column that indicates each movie's country of origin.
#
# By systematically addressing these problems, we aim to transform the raw dataset into a dependable resource for exploratory and descriptive analysis. The actual extraction of insights will be conducted in the subsequent project.

# %% [markdown]
# ## 3. Preparation

# %% [markdown]
# ### 3.1. Import Libraries

# %%
import pandas as pd
import os
import io
from io import StringIO

from dotenv import load_dotenv
import google.generativeai as genai

load_dotenv()
print("Pandas Version:", pd.__version__)
print("dotenv Version:", load_dotenv.__module__.split('.')[0], pd.__version__)

# For dotenv version
import importlib.metadata
print("python-dotenv Version:", importlib.metadata.version("python-dotenv"))

# For google.generativeai version
print("google-generativeai Version:", importlib.metadata.version("google-generativeai"))

print("Current Working Directory:", os.getcwd())
# Out:
# Pandas Version: 2.2.3
# dotenv Version: dotenv 2.2.3
# python-dotenv Version: 1.1.0
# google-generativeai Version: 0.8.5
# Current Working Directory: D:\Project\Github\FajarLaksono\analytics-dirty-imdb-data

# %% [markdown]
# ### 3.2. Load dataset

# %%
dataset_path = 'Datasets/01_Raw/Dirty_imdb_top_1000.csv'
df = pd.read_csv(dataset_path)

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 4.1. Data Preview

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkY...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate    Runtime  \
# 0  the shawshank redemption         1994.0         NaN   142 min
# 1            THE GODFATHER          1972.0           A   175 min
# 2           The Dark Knight         2008.0         UA     152 min
# 3    THE GODFATHER: PART II         1974.0          A     202 min
# 4             12 angry men          1957.0          U      96 min
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0   When the menace known as the Joker wreaks hav...        84.0
# 3          NaN                                                NaN        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                     Star1          Star2          Star3           Star4  \
# 0           Tim @ Robbins            NaN     Bob Gunton  William Sadler
# 1         Marlon @ Brando            NaN    James Caan    Diane Keaton
# 2   @ Christian @ Bale @    Heath Ledger  Aaron Eckhart   Michael Caine
# 3        @ Al @ Pacino @             NaN  Robert Duvall   Diane Keaton
# 4      @ Henry @ Fonda @    Lee J. Cobb   Martin Balsam             NaN
#
#    No_of_Votes        Gross                              Director_Genre
# 0    2343110.0   28,341,469                       Frank Darabont *Drama
# 1    1620367.0          NaN           Francis Ford Coppola*Crime, Drama
# 2    2303232.0  534,858,444   Christopher Nolan * Action, Crime, Drama
# 3          NaN          NaN        Francis Ford Coppola * Crime, Drama
# 4     689845.0    4,360,000                   Sidney Lumet*Crime, Drama

# %% [markdown]
# ### 4.2. Schema

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Poster_Link     902 non-null    object
#  1   Series_Title    901 non-null    object
#  2   Released_Year   900 non-null    float64
#  3   Certificate     813 non-null    object
#  4   Runtime         900 non-null    object
#  5   IMDB_Rating     900 non-null    float64
#  6   Overview        900 non-null    object
#  7   Meta_score      760 non-null    float64
#  8   Star1           900 non-null    object
#  9   Star2           900 non-null    object
#  10  Star3           900 non-null    object
#  11  Star4           900 non-null    object
#  12  No_of_Votes     900 non-null    float64
#  13  Gross           744 non-null    object
#  14  Director_Genre  900 non-null    object
# dtypes: float64(4), object(11)
# memory usage: 117.3+ KB

# %% [markdown]
# ### 4.3. Missing Values

# %%
df.isnull().sum()
# Out:
# Poster_Link        98
# Series_Title       99
# Released_Year     100
# Certificate       187
# Runtime           100
# IMDB_Rating       100
# Overview          100
# Meta_score        240
# Star1             100
# Star2             100
# Star3             100
# Star4             100
# No_of_Votes       100
# Gross             256
# Director_Genre    100
# dtype: int64

# %% [markdown]
# ### 4.4. Duplications

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 4.5. Summary
# 1. <ins>Duplications:</ins> No duplication is detected.
# 2. <ins>Concatenated fields:</ins> Director_Genre field is identified to be Concatenated.
# 3. <ins>Inconsistent Formating:</ins> Formarting Inconsistent is detected in some of the Categorical and Textual colomns.
# 4. <ins>Missing Column:</ins> The data is missing an important column that define the movies' country of origin.
# 5. <ins>Missing Values:</ins> Hundreds of values are missing from the respective columns.

# %% [markdown]
# ## 5. Data Cleaning

# %% [markdown]
# ### 5.1. Generate "ID" column
# ID is used to make data cleaning easier.

# %%
df.insert(0, 'ID', range(1, len(df) + 1))

# %% [markdown]
# ### 5.2. Clean Concatenated Fields

# %%
# ======= Split "Director_Genre" Column ======= 
df[['Director_Name', 'Genre']] = df["Director_Genre"].str.split('*', expand=True)
df.drop(columns=["Director_Genre"], inplace=True)
df.head()
# Out:
#    ID                                        Poster_Link  \
# 0   1   https://m.media-amazon.com/images/M/MV5BMDFkY...
# 1   2  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   3  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   4  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   5  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate    Runtime  \
# 0  the shawshank redemption         1994.0         NaN   142 min
# 1            THE GODFATHER          1972.0           A   175 min
# 2           The Dark Knight         2008.0         UA     152 min
# 3    THE GODFATHER: PART II         1974.0          A     202 min
# 4             12 angry men          1957.0          U      96 min
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0   When the menace known as the Joker wreaks hav...        84.0
# 3          NaN                                                NaN        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                     Star1          Star2          Star3           Star4  \
# 0           Tim @ Robbins            NaN     Bob Gunton  William Sadler
# 1         Marlon @ Brando            NaN    James Caan    Diane Keaton
# 2   @ Christian @ Bale @    Heath Ledger  Aaron Eckhart   Michael Caine
# 3        @ Al @ Pacino @             NaN  Robert Duvall   Diane Keaton
# 4      @ Henry @ Fonda @    Lee J. Cobb   Martin Balsam             NaN
#
#    No_of_Votes        Gross           Director_Name                   Genre
# 0    2343110.0   28,341,469         Frank Darabont                    Drama
# 1    1620367.0          NaN    Francis Ford Coppola            Crime, Drama
# 2    2303232.0  534,858,444      Christopher Nolan    Action, Crime, Drama
# 3          NaN          NaN   Francis Ford Coppola            Crime, Drama
# 4     689845.0    4,360,000            Sidney Lumet            Crime, Drama

# %% [markdown]
# ### 5.3. Handle the Inconsistency of Formating

# %%
import re

# ===== Standardize "Poster_Link" =====
df['Poster_Link'] = df['Poster_Link'].astype('string').str.strip()

# ===== Standardize "Series_Title" ===== 
def normalize_name(name):    
    if pd.isna(name):
        return pd.NA

    name = name.strip().lower()
    name = re.sub(r'\s+', ' ', name) 
    
    roman_pattern = r'^(?=[MDCLXVI])M{0,4}(CM|CD|D?C{0,3})?' \
                r'(XC|XL|L?X{0,3})?(IX|IV|V?I{0,3})$'

    words = name.split(' ')

    normalized = []
    for word in words: 
        if re.match(roman_pattern, word.upper()):
            normalized.append(word.upper())
        else:
            normalized.append(word.capitalize())

    return ' '.join(normalized)

df['Series_Title'] = df['Series_Title'].astype('string').apply(normalize_name)

# ===== Standardize "Released_Year" ===== 
# no action needed

# ===== Standardize "Certificaate" ===== 
df['Certificate'] = df['Certificate'].astype('string').str.strip().str.upper()

# ===== Standardize "Runtime" =====
df['Runtime'] = df['Runtime'].astype('string').str.strip().str.replace(' min', '', regex=False).apply(pd.to_numeric, errors='coerce').astype('Int64')
df.rename(columns={'Runtime': 'Runtime_Minutes'}, inplace=True)

# ===== Standardize "IMDB_Rating" =====
# no action needed

# ===== Standardize "Overview" =====
df['Overview'] = df['Overview'].astype('string').str.strip().replace(', ...', '.').str.replace('See full summary »', '')

# ===== Standardize "Meta_score" =====
# no action needed

# # ===== Standardize "Star1" =====
df['Star1'] = df['Star1'].astype('string').str.replace('@', '').apply(normalize_name)

# # ===== Standardize "Star2" =====
df['Star2'] = df['Star2'].astype('string').apply(normalize_name)

# ===== Standardize "Star3" =====
df['Star3'] = df['Star3'].astype('string').apply(normalize_name)

# ===== Standardize "Star4" =====
df['Star4'] = df['Star4'].astype('string').apply(normalize_name)

# ===== Standardize "No_of_Votes" =====
df['No_of_Votes'] = df['No_of_Votes'].astype('string').str.strip().astype('Float64')

# ===== Standardize "Gross" =====
df['Gross'] = df['Gross'].str.replace(',', '', regex=False).astype('Float64')

# # ===== Standardize "Director_Name" =====
df['Director_Name'] = df['Director_Name'].astype('string').apply(normalize_name)

# # ===== Standardize "Genre" =====
# # no action needed

df.head()
# Out:
#    ID                                        Poster_Link  \
# 0   1  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   2  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   3  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   4  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   5  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime_Minutes  \
# 0  The Shawshank Redemption         1994.0        <NA>              142
# 1             The Godfather         1972.0           A              175
# 2           The Dark Knight         2008.0          UA              152
# 3    The Godfather: Part II         1974.0           A              202
# 4              12 Angry Men         1957.0           U               96
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 3          NaN                                               <NA>        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#             Star1         Star2          Star3           Star4  No_of_Votes  \
# 0     Tim Robbins          <NA>     Bob Gunton  William Sadler    2343110.0
# 1   Marlon Brando          <NA>     James Caan    Diane Keaton    1620367.0
# 2  Christian Bale  Heath Ledger  Aaron Eckhart   Michael Caine    2303232.0
# 3       Al Pacino          <NA>  Robert Duvall    Diane Keaton         <NA>
# 4     Henry Fonda   Lee J. Cobb  Martin Balsam            <NA>     689845.0
#
#          Gross         Director_Name                   Genre
# 0   28341469.0        Frank Darabont                   Drama
# 1         <NA>  Francis Ford Coppola            Crime, Drama
# 2  534858444.0     Christopher Nolan   Action, Crime, Drama
# 3         <NA>  Francis Ford Coppola           Crime, Drama
# 4    4360000.0          Sidney Lumet            Crime, Drama

# %%
df.isnull().sum()
# Out:
# ID                   0
# Poster_Link         98
# Series_Title        99
# Released_Year      100
# Certificate        187
# Runtime_Minutes    100
# IMDB_Rating        100
# Overview           100
# Meta_score         240
# Star1              100
# Star2              100
# Star3              100
# Star4              100
# No_of_Votes        100
# Gross              256
# Director_Name      100
# Genre              100
# dtype: int64

# %% [markdown]
# ### 5.4. Recover Missing Data With AI

# %% [markdown]
# Check Important Values for GenAI

# %%
df[
    (df['Series_Title'].isnull() | df['Series_Title'].str.strip().eq('')) 
    & (df['Director_Name'].isnull() | df['Director_Name'].str.strip().eq('')) 
    & (df['Overview'].isnull() | df['Overview'].str.strip().eq('')) 
]
# Out:
#       ID                                        Poster_Link Series_Title  \
# 552  553  https://m.media-amazon.com/images/M/MV5BODcxYj...         <NA>
#
#      Released_Year Certificate  Runtime_Minutes  IMDB_Rating Overview  \
# 552         1956.0           U             <NA>          7.9     <NA>
#
#      Meta_score            Star1        Star2        Star3  \
# 552         NaN  Charlton Heston  Yul Brynner  Anne Baxter
#
#                   Star4  No_of_Votes       Gross Director_Name Genre
# 552  Edward G. Robinson      63560.0  93740000.0          <NA>   NaN

# %% [markdown]
# To retieve the Country values we can rely on existing values like Series_Title, Overview, or Director_Name.
# For the another 1 row, we can rely on the Star names and Year.

# %% [markdown]
# We will perform Gen AI processing to generate the Country colomn.

# %% [markdown]
# #### 5.4.1 Preparation

# %%
def generate_prompt(data, tasks):
    prompt = (
        "Tasks: \n"
        + str(tasks) +
        "\nRules: \n"
        " - Use the existing values as clues to find out the missing value, to fill in the missing cells or columns\n"
        " - If you cannot find the country origin or the missing value, just put 'Unknown' into the cell.\n"
        " - DO NOT provide any explanations, reasoning, or commentary.\n"
        " - DO NOT include any text before or after the dataset.\n"
        " - Return data in JSON format for easier parsing.\n"
        "\nResponse Format: \n"
        " - Provide ONLY a JSON array of objects.\n"
        " - Each object should have all the required fields.\n"
        " - Start immediately with the JSON array (no introductory text).\n"
        " - Ensure all missing values are filled in appropriately.\n"
        " - Example format: [{\"ID\": 1, \"Series_Title\": \"Movie Name\", \"Director_Name\": \"Director\", \"Overview\": \"Description\", \"Country_Origin\": \"USA\"}]\n"
        "\nThis is the data set:\n"
        + data.to_json(orient='records', indent=2)
    )
    return prompt


def extract_columns_as_clues(df, columns):
    return df[[col for col in columns]]


def parse_ai_response_to_dataframe(ai_response_text):
    import json
    try:
        # Clean the response - remove any markdown formatting
        clean_text = ai_response_text.strip()
        
        # Remove markdown code blocks if present
        if clean_text.startswith('```json'):
            clean_text = clean_text[7:]
        if clean_text.endswith('```'):
            clean_text = clean_text[:-3]
        clean_text = clean_text.strip()
        
        # Try to find JSON array in the response
        start_idx = clean_text.find('[')
        end_idx = clean_text.rfind(']') + 1
        
        if start_idx != -1 and end_idx > start_idx:
            json_text = clean_text[start_idx:end_idx]
            
            # Parse JSON and convert to DataFrame
            data = json.loads(json_text)
            df = pd.DataFrame(data)
            return df
        else:
            print("No JSON array found in response")
            return None
            
    except json.JSONDecodeError as e:
        print(f"JSON parsing error: {e}")
        print(f"Response text: {ai_response_text[:200]}...")
        return None
    except Exception as e:
        print(f"Error parsing AI response: {e}")
        print(f"Raw response: {ai_response_text[:200]}...")
        return None


def call_gemini_api(prompt):
    api_key = os.getenv('GEMINI_API_KEY')
    model_name = os.getenv("GEMINI_MODEL", "gemini-1.5-flash")

    if not api_key:
        print("GEMINI_API_KEY environment variable not set.")
    
    try:
        genai.configure(api_key=api_key)

        model = genai.GenerativeModel(model_name)

        response = model.generate_content(prompt)

        return response.text

    except Exception as e:
        print(f"Error calling Gemini API: {e}")

        return None
    

def process_data_in_batches(df, tasks, batch_size=50, max_retries=3):
    all_results = []
    total_batches = len(df) // batch_size + (1 if len(df) % batch_size != 0 else 0)
    
    print(f"Processing {len(df)} rows in {total_batches} batches of {batch_size} rows each...")
    
    for i in range(0, len(df), batch_size):
        batch_num = i // batch_size + 1
        batch = df.iloc[i:i+batch_size].copy()
        
        print(f"Processing batch {batch_num}/{total_batches} (rows {i+1}-{min(i+batch_size, len(df))})")
        
        success = False
        for retry in range(max_retries):
            try:
                prompt = generate_prompt(batch, tasks)
                
                print(f"Calling Gemini API for batch {batch_num} (attempt {retry + 1}/{max_retries})...")
                ai_response_text = call_gemini_api(prompt)
                print(f"Gemini API response received for batch {batch_num}")
                
                if ai_response_text:
                    print(f"Parsing AI response for batch {batch_num}...")
                    batch_result = parse_ai_response_to_dataframe(ai_response_text)
                    
                    if batch_result is not None and len(batch_result) > 0:
                        all_results.append(batch_result)
                        print(f"✓ Batch {batch_num} completed successfully")
                        success = True
                        break
                    else:
                        print(f"✗ Batch {batch_num} failed to parse (attempt {retry + 1}/{max_retries})")
                else:
                    print(f"✗ Batch {batch_num} API call failed (attempt {retry + 1}/{max_retries})")
                    
            except Exception as e:
                print(f"✗ Batch {batch_num} error: {e} (attempt {retry + 1}/{max_retries})")
        
        if not success:
            print(f"⚠️  Batch {batch_num} failed after {max_retries} attempts. Using original data.")
            all_results.append(batch)
    
    if all_results:
        combined_result = pd.concat(all_results, ignore_index=True)
        print(f"✓ All batches completed. Final dataset: {len(combined_result)} rows")
        return combined_result
    else:
        print("✗ No successful batches. Returning original data.")
        return df

# %% [markdown]
# #### 5.4.2. Recover Missing values and columns

# %%
series_director_overview_country_tasks_list = "1. Add a new column called 'Country_Origin' that tells the country origin of the Series/Movies, \n" \
"2. Fill in the missing value within the data.\n"

series_director_overview_country_prompt = generate_prompt(df, series_director_overview_country_tasks_list)

print(series_director_overview_country_prompt)
# Out:
# Tasks:
# 1. Add a new column called 'Country_Origin' that tells the country origin of the Series/Movies,
# 2. Fill in the missing value within the data.
#
# Rules:
#  - Use the existing values as clues to find out the missing value, to fill in the missing cells or columns
#  - If you cannot find the country origin or the missing value, just put 'Unknown' into the cell.
#  - DO NOT provide any explanations, reasoning, or commentary.
#  - DO NOT include any text before or after the dataset.
#  - Return data in JSON format for easier parsing.
#
# Response Format:
#  - Provide ONLY a JSON array of objects.
#  - Each object should have all the required fields.
#  - Start immediately with the JSON array (no introductory text).
#  - Ensure all missing values are filled in appropriately.
#  - Example format: [{"ID": 1, "Series_Title": "Movie Name", "Director_Name": "Director", "Overview": "Description", "Country_Origin": "USA"}]
#
# This is the data set:
# [
#   {
#     "ID":1,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Shawshank Redemption",
#     "Released_Year":1994.0,
#     "Certificate":null,
#     "Runtime_Minutes":142,
#     "IMDB_Rating":9.3,
#     "Overview":"Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.",
#     "Meta_score":80.0,
#     "Star1":"Tim Robbins",
#     "Star2":null,
#     "Star3":"Bob Gunton",
#     "Star4":"William Sadler",
#     "No_of_Votes":2343110.0,
#     "Gross":28341469.0,
#     "Director_Name":"Frank Darabont",
#     "Genre":"Drama"
#   },
#   {
#     "ID":2,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg",
#     "Series_Title":"The Godfather",
#     "Released_Year":1972.0,
#     "Certificate":"A",
#     "Runtime_Minutes":175,
#     "IMDB_Rating":9.2,
#     "Overview":"An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.",
#     "Meta_score":100.0,
#     "Star1":"Marlon Brando",
#     "Star2":null,
#     "Star3":"James Caan",
#     "Star4":"Diane Keaton",
#     "No_of_Votes":1620367.0,
#     "Gross":null,
#     "Director_Name":"Francis Ford Coppola",
#     "Genre":"Crime, Drama"
#   },
#   {
#     "ID":3,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Dark Knight",
#     "Released_Year":2008.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":152,
#     "IMDB_Rating":9.0,
#     "Overview":"When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.",
#     "Meta_score":84.0,
#     "Star1":"Christian Bale",
#     "Star2":"Heath Ledger",
#     "Star3":"Aaron Eckhart",
#     "Star4":"Michael Caine",
#     "No_of_Votes":2303232.0,
#     "Gross":534858444.0,
#     "Director_Name":"Christopher Nolan",
#     "Genre":" Action, Crime, Drama "
#   },
#   {
#     "ID":4,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg",
#     "Series_Title":"The Godfather: Part II",
#     "Released_Year":1974.0,
#     "Certificate":"A",
#     "Runtime_Minutes":202,
#     "IMDB_Rating":null,
#     "Overview":null,
#     "Meta_score":90.0,
#     "Star1":"Al Pacino",
#     "Star2":null,
#     "Star3":"Robert Duvall",
#     "Star4":"Diane Keaton",
#     "No_of_Votes":null,
#     "Gross":null,
#     "Director_Name":"Francis Ford Coppola",
#     "Genre":" Crime, Drama "
#   },
#   {
#     "ID":5,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"12 Angry Men",
#     "Released_Year":1957.0,
#     "Certificate":"U",
#     "Runtime_Minutes":96,
#     "IMDB_Rating":9.0,
#     "Overview":"A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.",
#     "Meta_score":96.0,
#     "Star1":"Henry Fonda",
#     "Star2":"Lee J. Cobb",
#     "Star3":"Martin Balsam",
#     "Star4":null,
#     "No_of_Votes":689845.0,
#     "Gross":4360000.0,
#     "Director_Name":"Sidney Lumet",
#     "Genre":"Crime, Drama"
#   },
#   {
#     "ID":6,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Lord Of The Rings: The Return Of The King",
#     "Released_Year":null,
#     "Certificate":"U",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":8.9,
#     "Overview":"Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#     "Meta_score":94.0,
#     "Star1":"Elijah Wood",
#     "Star2":null,
#     "Star3":"Ian Mckellen",
#     "Star4":"Orlando Bloom",
#     "No_of_Votes":1642758.0,
#     "Gross":377845905.0,
#     "Director_Name":"Peter Jackson",
#     "Genre":"Action, Adventure, Drama"
#   },
#   {
#     "ID":7,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Pulp Fiction",
#     "Released_Year":1994.0,
#     "Certificate":"A",
#     "Runtime_Minutes":154,
#     "IMDB_Rating":8.9,
#     "Overview":"The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.",
#     "Meta_score":94.0,
#     "Star1":"John Travolta",
#     "Star2":"Uma Thurman",
#     "Star3":"Samuel L. Jackson",
#     "Star4":"Bruce Willis",
#     "No_of_Votes":1826188.0,
#     "Gross":null,
#     "Director_Name":"Quentin Tarantino",
#     "Genre":"Crime, Drama"
#   },
#   {
#     "ID":8,
#     "Poster_Link":null,
#     "Series_Title":"Schindler's List",
#     "Released_Year":1993.0,
#     "Certificate":"A",
#     "Runtime_Minutes":195,
#     "IMDB_Rating":8.9,
#     "Overview":"In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.",
#     "Meta_score":94.0,
#     "Star1":"Liam Neeson",
#     "Star2":"Ralph Fiennes",
#     "Star3":"Ben Kingsley",
#     "Star4":"Caroline Goodall",
#     "No_of_Votes":null,
#     "Gross":96898818.0,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":9,
#     "Poster_Link":"https:\/\/upload.wikimedia.org\/wikipedia\/en\/2\/2e\/Inception_%282010%29_theatrical_poster.jpg",
#     "Series_Title":"Inception",
#     "Released_Year":2010.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":148,
#     "IMDB_Rating":8.8,
#     "Overview":"A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O.",
#     "Meta_score":74.0,
#     "Star1":"Leonardo Dicaprio",
#     "Star2":"Joseph Gordon-levitt",
#     "Star3":null,
#     "Star4":"Ken Watanabe",
#     "No_of_Votes":null,
#     "Gross":292576195.0,
#     "Director_Name":"Christopher Nolan",
#     "Genre":"Action, Adventure, Sci-Fi"
#   },
#   {
#     "ID":10,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMmEzNTkxYjQtZTc0MC00YTVjLTg5ZTEtZWMwOWVlYzY0NWIwXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Fight Club",
#     "Released_Year":1999.0,
#     "Certificate":"A",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":8.8,
#     "Overview":"An insomniac office worker and a devil-may-care soapmaker form an underground fight club that evolves into something much, much more.",
#     "Meta_score":null,
#     "Star1":null,
#     "Star2":null,
#     "Star3":"Meat Loaf",
#     "Star4":"Zach Grenier",
#     "No_of_Votes":1854740.0,
#     "Gross":37030102.0,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":11,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BN2EyZjM3NzUtNWUzMi00MTgxLWI0NTctMzY4M2VlOTdjZWRiXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Lord Of The Rings: The Fellowship Of The Ring",
#     "Released_Year":2001.0,
#     "Certificate":"U",
#     "Runtime_Minutes":178,
#     "IMDB_Rating":8.8,
#     "Overview":"A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.",
#     "Meta_score":92.0,
#     "Star1":"Elijah Wood",
#     "Star2":"Ian Mckellen",
#     "Star3":"Orlando Bloom",
#     "Star4":"Sean Bean",
#     "No_of_Votes":1661481.0,
#     "Gross":315544750.0,
#     "Director_Name":"Peter Jackson",
#     "Genre":" Action, Adventure, Drama "
#   },
#   {
#     "ID":12,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY98_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Forrest Gump",
#     "Released_Year":1994.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":142,
#     "IMDB_Rating":8.8,
#     "Overview":null,
#     "Meta_score":null,
#     "Star1":"Tom Hanks",
#     "Star2":"Robin Wright",
#     "Star3":null,
#     "Star4":"Sally Field",
#     "No_of_Votes":1809221.0,
#     "Gross":330252182.0,
#     "Director_Name":"Robert Zemeckis",
#     "Genre":" Drama, Romance "
#   },
#   {
#     "ID":13,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BOTQ5NDI3MTI4MF5BMl5BanBnXkFtZTgwNDQ4ODE5MDE@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Il Buono, Il Brutto, Il Cattivo",
#     "Released_Year":1966.0,
#     "Certificate":"A",
#     "Runtime_Minutes":161,
#     "IMDB_Rating":8.8,
#     "Overview":"A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.",
#     "Meta_score":90.0,
#     "Star1":"Clint Eastwood",
#     "Star2":"Eli Wallach",
#     "Star3":"Lee Van Cleef",
#     "Star4":"Aldo Giuffr\u00e8",
#     "No_of_Votes":688390.0,
#     "Gross":6100000.0,
#     "Director_Name":"Sergio Leone",
#     "Genre":"Western"
#   },
#   {
#     "ID":14,
#     "Poster_Link":"https:\/\/upload.wikimedia.org\/wikipedia\/en\/a\/a1\/Lord_Rings_Two_Towers.jpg",
#     "Series_Title":"The Lord Of The Rings: The Two Towers",
#     "Released_Year":2002.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":179,
#     "IMDB_Rating":8.7,
#     "Overview":"While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.",
#     "Meta_score":87.0,
#     "Star1":null,
#     "Star2":"Ian Mckellen",
#     "Star3":"Viggo Mortensen",
#     "Star4":"Orlando Bloom",
#     "No_of_Votes":1485555.0,
#     "Gross":342551365.0,
#     "Director_Name":"Peter Jackson",
#     "Genre":"Action, Adventure, Drama"
#   },
#   {
#     "ID":15,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNzQzOTk3OTAtNDQ0Zi00ZTVkLWI0MTEtMDllZjNkYzNjNTc4L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Matrix",
#     "Released_Year":1999.0,
#     "Certificate":"A",
#     "Runtime_Minutes":136,
#     "IMDB_Rating":8.7,
#     "Overview":"When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.",
#     "Meta_score":73.0,
#     "Star1":"Lilly Wachowski",
#     "Star2":"Keanu Reeves",
#     "Star3":"Laurence Fishburne",
#     "Star4":"Carrie-anne Moss",
#     "No_of_Votes":1676426.0,
#     "Gross":171479930.0,
#     "Director_Name":"Lana Wachowski",
#     "Genre":" Action, Sci-Fi "
#   },
#   {
#     "ID":16,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BY2NkZjEzMDgtN2RjYy00YzM1LWI4ZmQtMjIwYjFjNmI3ZGEwXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":1990.0,
#     "Certificate":"A",
#     "Runtime_Minutes":146,
#     "IMDB_Rating":8.7,
#     "Overview":"The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.",
#     "Meta_score":null,
#     "Star1":"Robert De Niro",
#     "Star2":"Ray Liotta",
#     "Star3":"Joe Pesci",
#     "Star4":null,
#     "No_of_Votes":1020727.0,
#     "Gross":46836394.0,
#     "Director_Name":"Martin Scorsese",
#     "Genre":"Biography, Crime, Drama"
#   },
#   {
#     "ID":17,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYmU1NDRjNDgtMzhiMi00NjZmLTg5NGItZDNiZjU5NTU4OTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Star Wars: Episode V - The Empire Strikes Back",
#     "Released_Year":null,
#     "Certificate":"UA",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":8.7,
#     "Overview":"After the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued by Darth Vader and a bounty hunter named Boba Fett all over the galaxy.",
#     "Meta_score":82.0,
#     "Star1":null,
#     "Star2":"Harrison Ford",
#     "Star3":"Carrie Fisher",
#     "Star4":"Billy Dee Williams",
#     "No_of_Votes":1159315.0,
#     "Gross":290475067.0,
#     "Director_Name":"Irvin Kershner",
#     "Genre":" Action, Adventure, Fantasy "
#   },
#   {
#     "ID":18,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZjA0OWVhOTAtYWQxNi00YzNhLWI4ZjYtNjFjZTEyYjJlNDVlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":null,
#     "Certificate":"A",
#     "Runtime_Minutes":133,
#     "IMDB_Rating":8.7,
#     "Overview":"A criminal pleads insanity and is admitted to a mental institution, where he rebels against the oppressive nurse and rallies up the scared patients.",
#     "Meta_score":83.0,
#     "Star1":null,
#     "Star2":"Louise Fletcher",
#     "Star3":"Michael Berryman",
#     "Star4":"Peter Brocco",
#     "No_of_Votes":null,
#     "Gross":112000000.0,
#     "Director_Name":"Milos Forman",
#     "Genre":"Drama"
#   },
#   {
#     "ID":19,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNjViNWRjYWEtZTI0NC00N2E3LTk0NGQtMjY4NTM3OGNkZjY0XkEyXkFqcGdeQXVyMjUxMTY3ODM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Hamilton",
#     "Released_Year":2020.0,
#     "Certificate":"PG-13",
#     "Runtime_Minutes":160,
#     "IMDB_Rating":null,
#     "Overview":"The real life of one of America's foremost founding fathers and first Secretary of the Treasury, Alexander Hamilton. Captured live on Broadway from the Richard Rodgers Theater with the original Broadway cast.",
#     "Meta_score":null,
#     "Star1":"Lin-manuel Miranda",
#     "Star2":"Phillipa Soo",
#     "Star3":"Leslie Odom Jr.",
#     "Star4":"Ren\u00e9e Elise Goldsberry",
#     "No_of_Votes":55291.0,
#     "Gross":null,
#     "Director_Name":"Thomas Kail",
#     "Genre":"Biography, Drama, History"
#   },
#   {
#     "ID":20,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYWZjMjk3ZTItODQ2ZC00NTY5LWE0ZDYtZTI3MjcwN2Q5NTVkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Gisaengchung",
#     "Released_Year":2019.0,
#     "Certificate":"A",
#     "Runtime_Minutes":132,
#     "IMDB_Rating":8.6,
#     "Overview":"Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.",
#     "Meta_score":96.0,
#     "Star1":"Kang-ho Song",
#     "Star2":"Lee Sun-kyun",
#     "Star3":null,
#     "Star4":"Choi Woo-sik",
#     "No_of_Votes":552778.0,
#     "Gross":53367844.0,
#     "Director_Name":"Bong Joon Ho",
#     "Genre":" Comedy, Drama, Thriller "
#   },
#   {
#     "ID":21,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BOTc2ZTlmYmItMDBhYS00YmMzLWI4ZjAtMTI5YTBjOTFiMGEwXkEyXkFqcGdeQXVyODE5NzE3OTE@._V1_UY98_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Soorarai Pottru",
#     "Released_Year":2020.0,
#     "Certificate":"U",
#     "Runtime_Minutes":153,
#     "IMDB_Rating":8.6,
#     "Overview":"Nedumaaran Rajangam \"Maara\" sets out to make the common man fly and in the process takes on the world's most capital intensive industry and several enemies who stand in his way.",
#     "Meta_score":null,
#     "Star1":"Suriya",
#     "Star2":"Madhavan",
#     "Star3":"Paresh Rawal",
#     "Star4":"Aparna Balamurali",
#     "No_of_Votes":54995.0,
#     "Gross":null,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":22,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Interstellar",
#     "Released_Year":null,
#     "Certificate":"UA",
#     "Runtime_Minutes":169,
#     "IMDB_Rating":8.6,
#     "Overview":"A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
#     "Meta_score":74.0,
#     "Star1":"Matthew Mcconaughey",
#     "Star2":"Anne Hathaway",
#     "Star3":"Jessica Chastain",
#     "Star4":"Mackenzie Foy",
#     "No_of_Votes":1512360.0,
#     "Gross":null,
#     "Director_Name":"Christopher Nolan",
#     "Genre":"Adventure, Drama, Sci-Fi"
#   },
#   {
#     "ID":23,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BOTMwYjc5ZmItYTFjZC00ZGQ3LTlkNTMtMjZiNTZlMWQzNzI5XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Cidade De Deus",
#     "Released_Year":2002.0,
#     "Certificate":null,
#     "Runtime_Minutes":130,
#     "IMDB_Rating":null,
#     "Overview":"In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.",
#     "Meta_score":79.0,
#     "Star1":"K\u00e1tia Lund",
#     "Star2":"Alexandre Rodrigues",
#     "Star3":"Leandro Firmino",
#     "Star4":"Matheus Nachtergaele",
#     "No_of_Votes":null,
#     "Gross":null,
#     "Director_Name":"Fernando Meirelles",
#     "Genre":"Crime, Drama"
#   },
#   {
#     "ID":24,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjlmZmI5MDctNDE2YS00YWE0LWE5ZWItZDBhYWQ0NTcxNWRhXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Sen To Chihiro No Kamikakushi",
#     "Released_Year":2001.0,
#     "Certificate":"U",
#     "Runtime_Minutes":125,
#     "IMDB_Rating":null,
#     "Overview":"During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches, and spirits, and where humans are changed into beasts.",
#     "Meta_score":96.0,
#     "Star1":"Daveigh Chase",
#     "Star2":"Suzanne Pleshette",
#     "Star3":"Miyu Irino",
#     "Star4":"Rumi Hiiragi",
#     "No_of_Votes":651376.0,
#     "Gross":10055859.0,
#     "Director_Name":"Hayao Miyazaki",
#     "Genre":" Animation, Adventure, Family "
#   },
#   {
#     "ID":25,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Saving Private Ryan",
#     "Released_Year":1998.0,
#     "Certificate":"R",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":8.6,
#     "Overview":null,
#     "Meta_score":91.0,
#     "Star1":"Tom Hanks",
#     "Star2":"Matt Damon",
#     "Star3":"Tom Sizemore",
#     "Star4":"Edward Burns",
#     "No_of_Votes":null,
#     "Gross":216540909.0,
#     "Director_Name":"Steven Spielberg",
#     "Genre":" Drama, War "
#   },
#   {
#     "ID":26,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Green Mile",
#     "Released_Year":1999.0,
#     "Certificate":"A",
#     "Runtime_Minutes":189,
#     "IMDB_Rating":8.6,
#     "Overview":"The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.",
#     "Meta_score":61.0,
#     "Star1":"Tom Hanks",
#     "Star2":null,
#     "Star3":"David Morse",
#     "Star4":"Bonnie Hunt",
#     "No_of_Votes":1147794.0,
#     "Gross":null,
#     "Director_Name":"Frank Darabont",
#     "Genre":"Crime, Drama, Fantasy"
#   },
#   {
#     "ID":27,
#     "Poster_Link":null,
#     "Series_Title":"La Vita \u00c8 Bella",
#     "Released_Year":1997.0,
#     "Certificate":null,
#     "Runtime_Minutes":116,
#     "IMDB_Rating":8.6,
#     "Overview":"When an open-minded Jewish librarian and his son become victims of the Holocaust, he uses a perfect mixture of will, humor, and imagination to protect his son from the dangers around their camp.",
#     "Meta_score":59.0,
#     "Star1":null,
#     "Star2":"Nicoletta Braschi",
#     "Star3":"Giorgio Cantarini",
#     "Star4":null,
#     "No_of_Votes":623629.0,
#     "Gross":57598247.0,
#     "Director_Name":"Roberto Benigni",
#     "Genre":" Comedy, Drama, Romance "
#   },
#   {
#     "ID":28,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BOTUwODM5MTctZjczMi00OTk4LTg3NWUtNmVhMTAzNTNjYjcyXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Se7en",
#     "Released_Year":1995.0,
#     "Certificate":"A",
#     "Runtime_Minutes":127,
#     "IMDB_Rating":null,
#     "Overview":"Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.",
#     "Meta_score":65.0,
#     "Star1":null,
#     "Star2":null,
#     "Star3":"Kevin Spacey",
#     "Star4":"Andrew Kevin Walker",
#     "No_of_Votes":null,
#     "Gross":100125643.0,
#     "Director_Name":"David Fincher",
#     "Genre":" Crime, Drama, Mystery "
#   },
#   {
#     "ID":29,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNjNhZTk0ZmEtNjJhMi00YzFlLWE1MmEtYzM1M2ZmMGMwMTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Silence Of The Lambs",
#     "Released_Year":1991.0,
#     "Certificate":"A",
#     "Runtime_Minutes":118,
#     "IMDB_Rating":8.6,
#     "Overview":"A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.",
#     "Meta_score":85.0,
#     "Star1":"Jodie Foster",
#     "Star2":"Anthony Hopkins",
#     "Star3":"Lawrence A. Bonney",
#     "Star4":"Kasi Lemmons",
#     "No_of_Votes":1270197.0,
#     "Gross":130742922.0,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":30,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNzVlY2MwMjktM2E4OS00Y2Y3LWE3ZjctYzhkZGM3YzA1ZWM2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Star Wars",
#     "Released_Year":1977.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":121,
#     "IMDB_Rating":null,
#     "Overview":"Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.",
#     "Meta_score":90.0,
#     "Star1":"Mark Hamill",
#     "Star2":"Harrison Ford",
#     "Star3":"Carrie Fisher",
#     "Star4":"Alec Guinness",
#     "No_of_Votes":1231473.0,
#     "Gross":322740140.0,
#     "Director_Name":"George Lucas",
#     "Genre":" Action, Adventure, Fantasy "
#   },
#   {
#     "ID":31,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYjBmYTQ1NjItZWU5MS00YjI0LTg2OTYtYmFkN2JkMmNiNWVkXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_UY98_CR2,0,67,98_AL_.jpg",
#     "Series_Title":"Seppuku",
#     "Released_Year":1962.0,
#     "Certificate":null,
#     "Runtime_Minutes":133,
#     "IMDB_Rating":8.6,
#     "Overview":"When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so challenges the clan's integrity.",
#     "Meta_score":85.0,
#     "Star1":"Tatsuya Nakadai",
#     "Star2":"Akira Ishihama",
#     "Star3":"Shima Iwashita",
#     "Star4":"Tetsur\u00f4 Tanba",
#     "No_of_Votes":42004.0,
#     "Gross":null,
#     "Director_Name":"Masaki Kobayashi",
#     "Genre":"Action, Drama, Mystery"
#   },
#   {
#     "ID":32,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BOWE4ZDdhNmMtNzE5ZC00NzExLTlhNGMtY2ZhYjYzODEzODA1XkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UY98_CR1,0,67,98_AL_.jpg",
#     "Series_Title":"Shichinin No Samurai",
#     "Released_Year":1954.0,
#     "Certificate":"U",
#     "Runtime_Minutes":207,
#     "IMDB_Rating":8.6,
#     "Overview":"A poor village under attack by bandits recruits seven unemployed samurai to help them defend themselves.",
#     "Meta_score":null,
#     "Star1":"Toshir\u00f4 Mifune",
#     "Star2":null,
#     "Star3":"Keiko Tsushima",
#     "Star4":"Yukiko Shimazaki",
#     "No_of_Votes":315744.0,
#     "Gross":269061.0,
#     "Director_Name":"Akira Kurosawa",
#     "Genre":"Action, Adventure, Drama"
#   },
#   {
#     "ID":33,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_UY98_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"It's A Wonderful Life",
#     "Released_Year":1946.0,
#     "Certificate":"PG",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":8.6,
#     "Overview":"An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.",
#     "Meta_score":89.0,
#     "Star1":"James Stewart",
#     "Star2":"Donna Reed",
#     "Star3":"Lionel Barrymore",
#     "Star4":"Thomas Mitchell",
#     "No_of_Votes":405801.0,
#     "Gross":null,
#     "Director_Name":"Frank Capra",
#     "Genre":"Drama, Family, Fantasy"
#   },
#   {
#     "ID":34,
#     "Poster_Link":null,
#     "Series_Title":"Joker",
#     "Released_Year":2019.0,
#     "Certificate":null,
#     "Runtime_Minutes":122,
#     "IMDB_Rating":8.5,
#     "Overview":"In Gotham City, mentally troubled comedian Arthur Fleck is disregarded and mistreated by society. He then embarks on a downward spiral of revolution and bloody crime. This path brings him face-to-face with his alter-ego: the Joker.",
#     "Meta_score":59.0,
#     "Star1":"Joaquin Phoenix",
#     "Star2":"Robert De Niro",
#     "Star3":"Zazie Beetz",
#     "Star4":"Frances Conroy",
#     "No_of_Votes":939252.0,
#     "Gross":335451311.0,
#     "Director_Name":"Todd Phillips",
#     "Genre":" Crime, Drama, Thriller "
#   },
#   {
#     "ID":35,
#     "Poster_Link":null,
#     "Series_Title":"Whiplash",
#     "Released_Year":null,
#     "Certificate":"A",
#     "Runtime_Minutes":106,
#     "IMDB_Rating":8.5,
#     "Overview":"A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#     "Meta_score":88.0,
#     "Star1":null,
#     "Star2":"J.k. Simmons",
#     "Star3":"Melissa Benoist",
#     "Star4":"Paul Reiser",
#     "No_of_Votes":717585.0,
#     "Gross":13092000.0,
#     "Director_Name":"Damien Chazelle",
#     "Genre":" Drama, Music "
#   },
#   {
#     "ID":36,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Intouchables",
#     "Released_Year":2011.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":112,
#     "IMDB_Rating":8.5,
#     "Overview":"After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.",
#     "Meta_score":57.0,
#     "Star1":"\u00c9ric Toledano",
#     "Star2":"Fran\u00e7ois Cluzet",
#     "Star3":"Omar Sy",
#     "Star4":"Anne Le Ny",
#     "No_of_Votes":760360.0,
#     "Gross":13182281.0,
#     "Director_Name":"Olivier Nakache",
#     "Genre":" Biography, Comedy, Drama "
#   },
#   {
#     "ID":37,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":2006.0,
#     "Certificate":"U",
#     "Runtime_Minutes":130,
#     "IMDB_Rating":8.5,
#     "Overview":"After a tragic accident, two stage magicians engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.",
#     "Meta_score":66.0,
#     "Star1":"Christian Bale",
#     "Star2":null,
#     "Star3":"Scarlett Johansson",
#     "Star4":"Michael Caine",
#     "No_of_Votes":1190259.0,
#     "Gross":53089891.0,
#     "Director_Name":"Christopher Nolan",
#     "Genre":"Drama, Mystery, Sci-Fi"
#   },
#   {
#     "ID":38,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Departed",
#     "Released_Year":2006.0,
#     "Certificate":"A",
#     "Runtime_Minutes":151,
#     "IMDB_Rating":8.5,
#     "Overview":"An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.",
#     "Meta_score":85.0,
#     "Star1":"Leonardo Dicaprio",
#     "Star2":"Matt Damon",
#     "Star3":"Jack Nicholson",
#     "Star4":"Mark Wahlberg",
#     "No_of_Votes":1189773.0,
#     "Gross":132384315.0,
#     "Director_Name":"Martin Scorsese",
#     "Genre":"Crime, Drama, Thriller"
#   },
#   {
#     "ID":39,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BOWRiZDIxZjktMTA1NC00MDQ2LWEzMjUtMTliZmY3NjQ3ODJiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY98_CR2,0,67,98_AL_.jpg",
#     "Series_Title":"The Pianist",
#     "Released_Year":2002.0,
#     "Certificate":null,
#     "Runtime_Minutes":150,
#     "IMDB_Rating":8.5,
#     "Overview":"A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II.",
#     "Meta_score":85.0,
#     "Star1":"Adrien Brody",
#     "Star2":null,
#     "Star3":null,
#     "Star4":"Emilia Fox",
#     "No_of_Votes":729603.0,
#     "Gross":null,
#     "Director_Name":"Roman Polanski",
#     "Genre":"Biography, Drama, Music"
#   },
#   {
#     "ID":40,
#     "Poster_Link":null,
#     "Series_Title":"Gladiator",
#     "Released_Year":2000.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":155,
#     "IMDB_Rating":8.5,
#     "Overview":"A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.",
#     "Meta_score":67.0,
#     "Star1":"Russell Crowe",
#     "Star2":"Joaquin Phoenix",
#     "Star3":"Connie Nielsen",
#     "Star4":"Oliver Reed",
#     "No_of_Votes":1341460.0,
#     "Gross":187705427.0,
#     "Director_Name":"Ridley Scott",
#     "Genre":" Action, Adventure, Drama "
#   },
#   {
#     "ID":41,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZjA0MTM4MTQtNzY5MC00NzY3LWI1ZTgtYzcxMjkyMzU4MDZiXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"American History X",
#     "Released_Year":1998.0,
#     "Certificate":"R",
#     "Runtime_Minutes":119,
#     "IMDB_Rating":8.5,
#     "Overview":"A former neo-nazi skinhead tries to prevent his younger brother from going down the same wrong path that he did.",
#     "Meta_score":62.0,
#     "Star1":null,
#     "Star2":"Edward Furlong",
#     "Star3":"Beverly D'angelo",
#     "Star4":"Jennifer Lien",
#     "No_of_Votes":1034705.0,
#     "Gross":null,
#     "Director_Name":"Tony Kaye",
#     "Genre":" Drama "
#   },
#   {
#     "ID":42,
#     "Poster_Link":null,
#     "Series_Title":"The Usual Suspects",
#     "Released_Year":1995.0,
#     "Certificate":"A",
#     "Runtime_Minutes":106,
#     "IMDB_Rating":8.5,
#     "Overview":"A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat, which began when five criminals met at a seemingly random police lineup.",
#     "Meta_score":77.0,
#     "Star1":"Kevin Spacey",
#     "Star2":"Gabriel Byrne",
#     "Star3":"Chazz Palminteri",
#     "Star4":"Stephen Baldwin",
#     "No_of_Votes":991208.0,
#     "Gross":23341568.0,
#     "Director_Name":"Bryan Singer",
#     "Genre":" Crime, Mystery, Thriller "
#   },
#   {
#     "ID":43,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BODllNWE0MmEtYjUwZi00ZjY3LThmNmQtZjZlMjI2YTZjYmQ0XkEyXkFqcGdeQXVyNTc1NTQxODI@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"L\u00e9on",
#     "Released_Year":1994.0,
#     "Certificate":"A",
#     "Runtime_Minutes":110,
#     "IMDB_Rating":8.5,
#     "Overview":"Mathilda, a 12-year-old girl, is reluctantly taken in by L\u00e9on, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his prot\u00e9g\u00e9e and learns the assassin's trade.",
#     "Meta_score":null,
#     "Star1":"Jean Reno",
#     "Star2":"Gary Oldman",
#     "Star3":"Natalie Portman",
#     "Star4":"Danny Aiello",
#     "No_of_Votes":1035236.0,
#     "Gross":19501238.0,
#     "Director_Name":"Luc Besson",
#     "Genre":"Action, Crime, Drama"
#   },
#   {
#     "ID":44,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Lion King",
#     "Released_Year":1994.0,
#     "Certificate":"U",
#     "Runtime_Minutes":88,
#     "IMDB_Rating":8.5,
#     "Overview":"Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.",
#     "Meta_score":88.0,
#     "Star1":"Rob Minkoff",
#     "Star2":"Matthew Broderick",
#     "Star3":"Jeremy Irons",
#     "Star4":null,
#     "No_of_Votes":942045.0,
#     "Gross":422783777.0,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":45,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Terminator 2: Judgment Day",
#     "Released_Year":1991.0,
#     "Certificate":"U",
#     "Runtime_Minutes":137,
#     "IMDB_Rating":8.5,
#     "Overview":"A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her teenage son, John Connor, from a more advanced and powerful cyborg.",
#     "Meta_score":75.0,
#     "Star1":"Arnold Schwarzenegger",
#     "Star2":"Linda Hamilton",
#     "Star3":null,
#     "Star4":null,
#     "No_of_Votes":null,
#     "Gross":null,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":46,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BM2FhYjEyYmYtMDI1Yy00YTdlLWI2NWQtYmEzNzAxOGY1NjY2XkEyXkFqcGdeQXVyNTA3NTIyNDg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":1988.0,
#     "Certificate":"U",
#     "Runtime_Minutes":155,
#     "IMDB_Rating":8.5,
#     "Overview":"A filmmaker recalls his childhood when falling in love with the pictures at the cinema of his home village and forms a deep friendship with the cinema's projectionist.",
#     "Meta_score":80.0,
#     "Star1":"Philippe Noiret",
#     "Star2":"Enzo Cannavale",
#     "Star3":"Antonella Attili",
#     "Star4":"Isa Danieli",
#     "No_of_Votes":230763.0,
#     "Gross":11990401.0,
#     "Director_Name":"Giuseppe Tornatore",
#     "Genre":" Drama, Romance "
#   },
#   {
#     "ID":47,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZmY2NjUzNDQtNTgxNC00M2Q4LTljOWQtMjNjNDBjNWUxNmJlXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Hotaru No Haka",
#     "Released_Year":1988.0,
#     "Certificate":"U",
#     "Runtime_Minutes":89,
#     "IMDB_Rating":8.5,
#     "Overview":"A young boy and his little sister struggle to survive in Japan during World War II.",
#     "Meta_score":94.0,
#     "Star1":"Tsutomu Tatsumi",
#     "Star2":"Ayano Shiraishi",
#     "Star3":"Akemi Yamaguchi",
#     "Star4":null,
#     "No_of_Votes":235231.0,
#     "Gross":null,
#     "Director_Name":"Isao Takahata",
#     "Genre":"Animation, Drama, War"
#   },
#   {
#     "ID":48,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Back To The Future",
#     "Released_Year":1985.0,
#     "Certificate":"U",
#     "Runtime_Minutes":116,
#     "IMDB_Rating":8.5,
#     "Overview":"Marty McFly, a 17-year-old high school student, is accidentally sent thirty years into the past in a time-traveling DeLorean invented by his close friend, the eccentric scientist Doc Brown.",
#     "Meta_score":null,
#     "Star1":"Michael J. Fox",
#     "Star2":"Christopher Lloyd",
#     "Star3":"Lea Thompson",
#     "Star4":"Crispin Glover",
#     "No_of_Votes":1058081.0,
#     "Gross":null,
#     "Director_Name":"Robert Zemeckis",
#     "Genre":"Adventure, Comedy, Sci-Fi"
#   },
#   {
#     "ID":49,
#     "Poster_Link":null,
#     "Series_Title":"Once Upon A Time In The West",
#     "Released_Year":1968.0,
#     "Certificate":"U",
#     "Runtime_Minutes":165,
#     "IMDB_Rating":8.5,
#     "Overview":"A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.",
#     "Meta_score":80.0,
#     "Star1":"Henry Fonda",
#     "Star2":"Charles Bronson",
#     "Star3":"Claudia Cardinale",
#     "Star4":"Jason Robards",
#     "No_of_Votes":302844.0,
#     "Gross":5321508.0,
#     "Director_Name":"Sergio Leone",
#     "Genre":" Western "
#   },
#   {
#     "ID":50,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Psycho",
#     "Released_Year":1960.0,
#     "Certificate":"A",
#     "Runtime_Minutes":109,
#     "IMDB_Rating":8.5,
#     "Overview":"A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run, and checks into a remote motel run by a young man under the domination of his mother.",
#     "Meta_score":97.0,
#     "Star1":"Anthony Perkins",
#     "Star2":"Janet Leigh",
#     "Star3":"Vera Miles",
#     "Star4":"John Gavin",
#     "No_of_Votes":604211.0,
#     "Gross":null,
#     "Director_Name":"Alfred Hitchcock",
#     "Genre":"Horror, Mystery, Thriller"
#   },
#   {
#     "ID":51,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Casablanca",
#     "Released_Year":1942.0,
#     "Certificate":"U",
#     "Runtime_Minutes":102,
#     "IMDB_Rating":8.5,
#     "Overview":"A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.",
#     "Meta_score":100.0,
#     "Star1":"Humphrey Bogart",
#     "Star2":"Ingrid Bergman",
#     "Star3":"Paul Henreid",
#     "Star4":"Claude Rains",
#     "No_of_Votes":522093.0,
#     "Gross":1024560.0,
#     "Director_Name":"Michael Curtiz",
#     "Genre":"Drama, Romance, War"
#   },
#   {
#     "ID":52,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Modern Times",
#     "Released_Year":1936.0,
#     "Certificate":"G",
#     "Runtime_Minutes":87,
#     "IMDB_Rating":8.5,
#     "Overview":"The Tramp struggles to live in modern industrial society with the help of a young homeless woman.",
#     "Meta_score":96.0,
#     "Star1":null,
#     "Star2":null,
#     "Star3":null,
#     "Star4":"Tiny Sandford",
#     "No_of_Votes":217881.0,
#     "Gross":163245.0,
#     "Director_Name":"Charles Chaplin",
#     "Genre":" Comedy, Drama, Family "
#   },
#   {
#     "ID":53,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BY2I4MmM1N2EtM2YzOS00OWUzLTkzYzctNDc5NDg2N2IyODJmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"City Lights",
#     "Released_Year":1931.0,
#     "Certificate":"G",
#     "Runtime_Minutes":87,
#     "IMDB_Rating":8.5,
#     "Overview":null,
#     "Meta_score":99.0,
#     "Star1":"Charles Chaplin",
#     "Star2":"Virginia Cherrill",
#     "Star3":"Florence Lee",
#     "Star4":"Harry Myers",
#     "No_of_Votes":167839.0,
#     "Gross":19181.0,
#     "Director_Name":"Charles Chaplin",
#     "Genre":" Comedy, Drama, Romance "
#   },
#   {
#     "ID":54,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMmExNzU2ZWMtYzUwYi00YmM2LTkxZTQtNmVhNjY0NTMyMWI2XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Capharna\u00fcm",
#     "Released_Year":2018.0,
#     "Certificate":"A",
#     "Runtime_Minutes":126,
#     "IMDB_Rating":null,
#     "Overview":"While serving a five-year sentence for a violent crime, a 12-year-old boy sues his parents for neglect.",
#     "Meta_score":75.0,
#     "Star1":"Zain Al Rafeea",
#     "Star2":"Yordanos Shiferaw",
#     "Star3":"Boluwatife Treasure Bankole",
#     "Star4":"Kawsar Al Haddad",
#     "No_of_Votes":62635.0,
#     "Gross":null,
#     "Director_Name":"Nadine Labaki",
#     "Genre":" Drama "
#   },
#   {
#     "ID":55,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNWJhMDlmZGUtYzcxNS00NDRiLWIwNjktNDY1Mjg3ZjBkYzY0XkEyXkFqcGdeQXVyMTU4MjUwMjI@._V1_UY98_CR2,0,67,98_AL_.jpg",
#     "Series_Title":"Ayla: The Daughter Of War",
#     "Released_Year":2017.0,
#     "Certificate":null,
#     "Runtime_Minutes":125,
#     "IMDB_Rating":8.4,
#     "Overview":"In 1950, amid-st the ravages of the Korean War, Sergeant S\u00fcleyman stumbles upon a half-frozen little girl, with no parents and no help in sight. Frantic, scared and on the verge of death, ...                See full summary\u00a0\u00bb",
#     "Meta_score":null,
#     "Star1":"Erdem Can",
#     "Star2":"\u00c7etin Tekindor",
#     "Star3":"Ismail Hacioglu",
#     "Star4":"Kyung-jin Lee",
#     "No_of_Votes":34112.0,
#     "Gross":null,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":56,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BY2FiMTFmMzMtZDI2ZC00NDQyLWExYTUtOWNmZWM1ZDg5YjVjXkEyXkFqcGdeQXVyODIwMDI1NjM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Vikram Vedha",
#     "Released_Year":2017.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":147,
#     "IMDB_Rating":8.4,
#     "Overview":"Vikram, a no-nonsense police officer, accompanied by Simon, his partner, is on the hunt to capture Vedha, a smuggler and a murderer. Vedha tries to change Vikram's life, which leads to a conflict.",
#     "Meta_score":null,
#     "Star1":"Pushkar",
#     "Star2":"Madhavan",
#     "Star3":"Vijay Sethupathi",
#     "Star4":"Shraddha Srinath",
#     "No_of_Votes":28401.0,
#     "Gross":null,
#     "Director_Name":"Gayatri",
#     "Genre":"Action, Crime, Drama"
#   },
#   {
#     "ID":57,
#     "Poster_Link":null,
#     "Series_Title":"Kimi No Na Wa.",
#     "Released_Year":2016.0,
#     "Certificate":"U",
#     "Runtime_Minutes":106,
#     "IMDB_Rating":8.4,
#     "Overview":"Two strangers find themselves linked in a bizarre way. When a connection forms, will distance be the only thing to keep them apart?",
#     "Meta_score":79.0,
#     "Star1":"Ry\u00fbnosuke Kamiki",
#     "Star2":"Mone Kamishiraishi",
#     "Star3":"Ry\u00f4 Narita",
#     "Star4":"Aoi Y\u00fbki",
#     "No_of_Votes":194838.0,
#     "Gross":5017246.0,
#     "Director_Name":"Makoto Shinkai",
#     "Genre":" Animation, Drama, Fantasy "
#   },
#   {
#     "ID":58,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTQ4MzQzMzM2Nl5BMl5BanBnXkFtZTgwMTQ1NzU3MDI@._V1_UY98_CR1,0,67,98_AL_.jpg",
#     "Series_Title":"Dangal",
#     "Released_Year":2016.0,
#     "Certificate":"U",
#     "Runtime_Minutes":161,
#     "IMDB_Rating":8.4,
#     "Overview":"Former wrestler Mahavir Singh Phogat and his two wrestler daughters struggle towards glory at the Commonwealth Games in the face of societal oppression.",
#     "Meta_score":null,
#     "Star1":null,
#     "Star2":"Sakshi Tanwar",
#     "Star3":null,
#     "Star4":"Sanya Malhotra",
#     "No_of_Votes":156479.0,
#     "Gross":12391761.0,
#     "Director_Name":"Nitesh Tiwari",
#     "Genre":"Action, Biography, Drama"
#   },
#   {
#     "ID":59,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjMwNDkxMTgzOF5BMl5BanBnXkFtZTgwNTkwNTQ3NjM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Spider-man: Into The Spider-verse",
#     "Released_Year":2018.0,
#     "Certificate":"U",
#     "Runtime_Minutes":117,
#     "IMDB_Rating":null,
#     "Overview":"Teen Miles Morales becomes the Spider-Man of his universe, and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.",
#     "Meta_score":87.0,
#     "Star1":"Peter Ramsey",
#     "Star2":"Rodney Rothman",
#     "Star3":"Shameik Moore",
#     "Star4":"Jake Johnson",
#     "No_of_Votes":375110.0,
#     "Gross":null,
#     "Director_Name":"Bob Persichetti",
#     "Genre":" Animation, Action, Adventure "
#   },
#   {
#     "ID":60,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Avengers: Endgame",
#     "Released_Year":2019.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":181,
#     "IMDB_Rating":8.4,
#     "Overview":"After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#     "Meta_score":78.0,
#     "Star1":"Joe Russo",
#     "Star2":"Robert Downey Jr.",
#     "Star3":"Chris Evans",
#     "Star4":"Mark Ruffalo",
#     "No_of_Votes":809955.0,
#     "Gross":858373000.0,
#     "Director_Name":null,
#     "Genre":null
#   },
#   {
#     "ID":61,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":null,
#     "Certificate":"UA",
#     "Runtime_Minutes":149,
#     "IMDB_Rating":8.4,
#     "Overview":"The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.",
#     "Meta_score":68.0,
#     "Star1":"Joe Russo",
#     "Star2":"Robert Downey Jr.",
#     "Star3":"Chris Hemsworth",
#     "Star4":"Mark Ruffalo",
#     "No_of_Votes":834477.0,
#     "Gross":678815482.0,
#     "Director_Name":"Anthony Russo",
#     "Genre":"Action, Adventure, Sci-Fi"
#   },
#   {
#     "ID":62,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_UY98_CR1,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":2017.0,
#     "Certificate":"U",
#     "Runtime_Minutes":105,
#     "IMDB_Rating":8.4,
#     "Overview":null,
#     "Meta_score":81.0,
#     "Star1":"Adrian Molina",
#     "Star2":null,
#     "Star3":"Gael Garc\u00eda Bernal",
#     "Star4":"Benjamin Bratt",
#     "No_of_Votes":384171.0,
#     "Gross":209726015.0,
#     "Director_Name":"Lee Unkrich",
#     "Genre":"Animation, Adventure, Family"
#   },
#   {
#     "ID":63,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjIyNTQ5NjQ1OV5BMl5BanBnXkFtZTcwODg1MDU4OA@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Django Unchained",
#     "Released_Year":2012.0,
#     "Certificate":"A",
#     "Runtime_Minutes":165,
#     "IMDB_Rating":8.4,
#     "Overview":"With the help of a German bounty hunter, a freed slave sets out to rescue his wife from a brutal Mississippi plantation owner.",
#     "Meta_score":81.0,
#     "Star1":"Jamie Foxx",
#     "Star2":"Christoph Waltz",
#     "Star3":"Leonardo Dicaprio",
#     "Star4":"Kerry Washington",
#     "No_of_Votes":1357682.0,
#     "Gross":162805434.0,
#     "Director_Name":"Quentin Tarantino",
#     "Genre":" Drama, Western "
#   },
#   {
#     "ID":64,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":2012.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":164,
#     "IMDB_Rating":8.4,
#     "Overview":"Eight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Catwoman, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane.",
#     "Meta_score":78.0,
#     "Star1":"Christian Bale",
#     "Star2":"Tom Hardy",
#     "Star3":"Anne Hathaway",
#     "Star4":"Gary Oldman",
#     "No_of_Votes":1516346.0,
#     "Gross":448139099.0,
#     "Director_Name":"Christopher Nolan",
#     "Genre":" Action, Adventure "
#   },
#   {
#     "ID":65,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNTkyOGVjMGEtNmQzZi00NzFlLTlhOWQtODYyMDc2ZGJmYzFhXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY98_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"3 Idiots",
#     "Released_Year":2009.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":170,
#     "IMDB_Rating":8.4,
#     "Overview":"Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of the world called them \"idiots\".",
#     "Meta_score":67.0,
# ...
#     "Series_Title":"Planes, Trains & Automobiles",
#     "Released_Year":1987.0,
#     "Certificate":null,
#     "Runtime_Minutes":93,
#     "IMDB_Rating":7.6,
#     "Overview":null,
#     "Meta_score":72.0,
#     "Star1":"Steve Martin",
#     "Star2":"John Candy",
#     "Star3":"Laila Robins",
#     "Star4":"Michael Mckean",
#     "No_of_Votes":124773.0,
#     "Gross":49530280.0,
#     "Director_Name":"John Hughes",
#     "Genre":"Comedy, Drama"
#   },
#   {
#     "ID":980,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZTllNWNlZjctMWQwMS00ZDc3LTg5ZjMtNzhmNzhjMmVhYTFlXkEyXkFqcGdeQXVyNTc1NTQxODI@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Lethal Weapon",
#     "Released_Year":1987.0,
#     "Certificate":"A",
#     "Runtime_Minutes":109,
#     "IMDB_Rating":7.6,
#     "Overview":"Two newly paired cops who are complete opposites must put aside their differences in order to catch a gang of drug smugglers.",
#     "Meta_score":68.0,
#     "Star1":"Mel Gibson",
#     "Star2":"Danny Glover",
#     "Star3":"Gary Busey",
#     "Star4":"Mitchell Ryan",
#     "No_of_Votes":236894.0,
#     "Gross":65207127.0,
#     "Director_Name":"Richard Donner",
#     "Genre":" Action, Crime, Thriller "
#   },
#   {
#     "ID":981,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZmI5YzM1MjItMzFmNy00NGFkLThlMDUtZjZmYTZkM2QxMjU3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Blood Simple",
#     "Released_Year":1984.0,
#     "Certificate":"A",
#     "Runtime_Minutes":99,
#     "IMDB_Rating":7.6,
#     "Overview":"The owner of a seedy small-town Texas bar discovers that one of his employees is having an affair with his wife. A chaotic chain of misunderstandings, lies and mischief ensues after he devises a plot to have them murdered.",
#     "Meta_score":82.0,
#     "Star1":"Ethan Coen",
#     "Star2":"John Getz",
#     "Star3":"Frances Mcdormand",
#     "Star4":"Dan Hedaya",
#     "No_of_Votes":87745.0,
#     "Gross":2150000.0,
#     "Director_Name":"Joel Coen",
#     "Genre":"Crime, Drama, Thriller"
#   },
#   {
#     "ID":982,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNWQ4MGZlZmYtZjY0MS00N2JhLWE0NmMtOTMwMTk4NDQ4NjE2XkEyXkFqcGdeQXVyNTI4MjkwNjA@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"On Golden Pond",
#     "Released_Year":1981.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":109,
#     "IMDB_Rating":7.6,
#     "Overview":"Norman is a curmudgeon with an estranged relationship with his daughter Chelsea. At Golden Pond, he and his wife nevertheless agree to care for Billy, the son of Chelsea's new boyfriend, and a most unexpected relationship blooms.",
#     "Meta_score":68.0,
#     "Star1":"Katharine Hepburn",
#     "Star2":"Henry Fonda",
#     "Star3":"Jane Fonda",
#     "Star4":null,
#     "No_of_Votes":null,
#     "Gross":119285432.0,
#     "Director_Name":"Mark Rydell",
#     "Genre":" Drama "
#   },
#   {
#     "ID":983,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BN2VlNjNhZWQtMTY2OC00Y2E1LWJkNGUtMDU4M2ViNzliMGYwXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Mad Max 2",
#     "Released_Year":1981.0,
#     "Certificate":"A",
#     "Runtime_Minutes":96,
#     "IMDB_Rating":7.6,
#     "Overview":"In the post-apocalyptic Australian wasteland, a cynical drifter agrees to help a small, gasoline-rich community escape a horde of bandits.",
#     "Meta_score":77.0,
#     "Star1":"Mel Gibson",
#     "Star2":"Bruce Spence",
#     "Star3":"Michael Preston",
#     "Star4":"Max Phipps",
#     "No_of_Votes":166588.0,
#     "Gross":null,
#     "Director_Name":"George Miller",
#     "Genre":" Action, Adventure, Sci-Fi "
#   },
#   {
#     "ID":984,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYTU2MWRiMTMtYzAzZi00NGYzLTlkMDEtNWQ3MzZlNTJlNzZkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Warriors",
#     "Released_Year":1979.0,
#     "Certificate":"UA",
#     "Runtime_Minutes":92,
#     "IMDB_Rating":null,
#     "Overview":"In the near future, a charismatic leader summons the street gangs of New York City in a bid to take it over. When he is killed, The Warriors are falsely blamed and now must fight their way home while every other gang is hunting them down.",
#     "Meta_score":65.0,
#     "Star1":"Michael Beck",
#     "Star2":"James Remar",
#     "Star3":"Dorsey Wright",
#     "Star4":"Brian Tyler",
#     "No_of_Votes":93878.0,
#     "Gross":22490039.0,
#     "Director_Name":"Walter Hill",
#     "Genre":"Action, Crime, Thriller"
#   },
#   {
#     "ID":985,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMGQ0OGM5YjItYzYyMi00NmVmLWI3ODMtMTY2NGRkZmI5MWU2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":1979.0,
#     "Certificate":"U",
#     "Runtime_Minutes":95,
#     "IMDB_Rating":7.6,
#     "Overview":"Kermit and his newfound friends trek across America to find success in Hollywood, but a frog legs merchant is after Kermit.",
#     "Meta_score":74.0,
#     "Star1":"Jim Henson",
#     "Star2":null,
#     "Star3":"Jerry Nelson",
#     "Star4":"Richard Hunt",
#     "No_of_Votes":32802.0,
#     "Gross":76657000.0,
#     "Director_Name":"James Frawley",
#     "Genre":" Adventure, Comedy, Family "
#   },
#   {
#     "ID":986,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNDQ3MzNjMDItZjE0ZS00ZTYxLTgxNTAtM2I4YjZjNWFjYjJlL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":1979.0,
#     "Certificate":"A",
#     "Runtime_Minutes":112,
#     "IMDB_Rating":7.6,
#     "Overview":"Alcatraz is the most secure prison of its time. It is believed that no one can ever escape from it, until three daring men make a possible successful attempt at escaping from one of the most infamous prisons in the world.",
#     "Meta_score":null,
#     "Star1":"Clint Eastwood",
#     "Star2":"Patrick Mcgoohan",
#     "Star3":"Roberts Blossom",
#     "Star4":"Jack Thibeau",
#     "No_of_Votes":121731.0,
#     "Gross":43000000.0,
#     "Director_Name":"Don Siegel",
#     "Genre":" Action, Biography, Crime "
#   },
#   {
#     "ID":987,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMzZiODUwNzktNzBiZi00MDc4LThkMGMtZmE3MTE0M2E1MTM3L2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Watership Down",
#     "Released_Year":1978.0,
#     "Certificate":"U",
#     "Runtime_Minutes":91,
#     "IMDB_Rating":7.6,
#     "Overview":"Hoping to escape destruction by human developers and save their community, a colony of rabbits, led by Hazel and Fiver, seek out a safe place to set up a new warren.",
#     "Meta_score":64.0,
#     "Star1":"John Hubley",
#     "Star2":null,
#     "Star3":"Richard Briers",
#     "Star4":"Ralph Richardson",
#     "No_of_Votes":33656.0,
#     "Gross":null,
#     "Director_Name":"Martin Rosen",
#     "Genre":" Animation, Adventure, Drama "
#   },
#   {
#     "ID":988,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNDU1MjQ0YWMtMWQ2MS00NTdmLTg1MGItNDA5NTNkNTRhOTIyXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Midnight Express",
#     "Released_Year":1978.0,
#     "Certificate":"A",
#     "Runtime_Minutes":121,
#     "IMDB_Rating":7.6,
#     "Overview":"Billy Hayes, an American college student, is caught smuggling drugs out of Turkey and thrown into prison.",
#     "Meta_score":null,
#     "Star1":"Brad Davis",
#     "Star2":"Irene Miracle",
#     "Star3":"Bo Hopkins",
#     "Star4":"Paolo Bonacelli",
#     "No_of_Votes":73662.0,
#     "Gross":35000000.0,
#     "Director_Name":"Alan Parker",
#     "Genre":" Biography, Crime, Drama "
#   },
#   {
#     "ID":989,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjM1NjE5NjQxN15BMl5BanBnXkFtZTgwMjYzMzQxMDE@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Close Encounters Of The Third Kind",
#     "Released_Year":1977.0,
#     "Certificate":"U",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":7.6,
#     "Overview":"Roy Neary, an electric lineman, watches how his quiet and ordinary daily life turns upside down after a close encounter with a UFO.",
#     "Meta_score":90.0,
#     "Star1":"Richard Dreyfuss",
#     "Star2":"Fran\u00e7ois Truffaut",
#     "Star3":"Teri Garr",
#     "Star4":"Melinda Dillon",
#     "No_of_Votes":null,
#     "Gross":null,
#     "Director_Name":"Steven Spielberg",
#     "Genre":" Drama, Sci-Fi "
#   },
#   {
#     "ID":990,
#     "Poster_Link":null,
#     "Series_Title":"The Long Goodbye",
#     "Released_Year":1973.0,
#     "Certificate":"A",
#     "Runtime_Minutes":112,
#     "IMDB_Rating":7.6,
#     "Overview":"Private investigator Philip Marlowe helps a friend out of a jam, but in doing so gets implicated in his wife's murder.",
#     "Meta_score":87.0,
#     "Star1":"Elliott Gould",
#     "Star2":"Nina Van Pallandt",
#     "Star3":null,
#     "Star4":"Mark Rydell",
#     "No_of_Votes":26337.0,
#     "Gross":959000.0,
#     "Director_Name":"Robert Altman",
#     "Genre":"Comedy, Crime, Drama"
#   },
#   {
#     "ID":991,
#     "Poster_Link":null,
#     "Series_Title":"Gi\u00f9 La Testa",
#     "Released_Year":1971.0,
#     "Certificate":"PG",
#     "Runtime_Minutes":157,
#     "IMDB_Rating":7.6,
#     "Overview":null,
#     "Meta_score":77.0,
#     "Star1":"Rod Steiger",
#     "Star2":"James Coburn",
#     "Star3":"Romolo Valli",
#     "Star4":"Maria Monti",
#     "No_of_Votes":30144.0,
#     "Gross":696690.0,
#     "Director_Name":"Sergio Leone",
#     "Genre":"Drama, War, Western"
#   },
#   {
#     "ID":992,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMzAyNDUwYzUtN2NlMC00ODliLWExMjgtMGMzNmYzZmUwYTg1XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":1970.0,
#     "Certificate":"GP",
#     "Runtime_Minutes":144,
#     "IMDB_Rating":7.6,
#     "Overview":"A group of U.S. soldiers sneaks across enemy lines to get their hands on a secret stash of Nazi treasure.",
#     "Meta_score":50.0,
#     "Star1":"Clint Eastwood",
#     "Star2":"Telly Savalas",
#     "Star3":"Don Rickles",
#     "Star4":"Carroll O'connor",
#     "No_of_Votes":45338.0,
#     "Gross":1378435.0,
#     "Director_Name":"Brian G. Hutton",
#     "Genre":" Adventure, Comedy, War "
#   },
#   {
#     "ID":993,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMjAwMTExODExNl5BMl5BanBnXkFtZTgwMjM2MDgyMTE@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The Jungle Book",
#     "Released_Year":1967.0,
#     "Certificate":"U",
#     "Runtime_Minutes":78,
#     "IMDB_Rating":7.6,
#     "Overview":"Bagheera the Panther and Baloo the Bear have a difficult time trying to convince a boy to leave the jungle for human civilization.",
#     "Meta_score":65.0,
#     "Star1":"Phil Harris",
#     "Star2":"Sebastian Cabot",
#     "Star3":"Louis Prima",
#     "Star4":"Bruce Reitherman",
#     "No_of_Votes":166409.0,
#     "Gross":141843612.0,
#     "Director_Name":"Wolfgang Reitherman",
#     "Genre":" Animation, Adventure, Family "
#   },
#   {
#     "ID":994,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYTE4YWU0NjAtMjNiYi00MTNiLTgwYzctZjk0YjY5NGVhNWQwXkEyXkFqcGdeQXVyMTY5Nzc4MDY@._V1_UY98_CR0,0,67,98_AL_.jpg",
#     "Series_Title":null,
#     "Released_Year":null,
#     "Certificate":"A",
#     "Runtime_Minutes":111,
#     "IMDB_Rating":7.6,
#     "Overview":"A fashion photographer unknowingly captures a death on film after following two lovers in a park.",
#     "Meta_score":82.0,
#     "Star1":"David Hemmings",
#     "Star2":"Vanessa Redgrave",
#     "Star3":"Sarah Miles",
#     "Star4":null,
#     "No_of_Votes":56513.0,
#     "Gross":null,
#     "Director_Name":"Michelangelo Antonioni",
#     "Genre":" Drama, Mystery, Thriller "
#   },
#   {
#     "ID":995,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZjQyMGUwNzAtNTc2MC00Y2FjLThlM2ItZGRjNzM0OWVmZGYyXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"A Hard Day's Night",
#     "Released_Year":1964.0,
#     "Certificate":"U",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":7.6,
#     "Overview":"Over two \"typical\" days in the life of The Beatles, the boys struggle to keep themselves and Sir Paul McCartney's mischievous grandfather in check while preparing for a live television performance.",
#     "Meta_score":96.0,
#     "Star1":"John Lennon",
#     "Star2":"Paul Mccartney",
#     "Star3":"George Harrison",
#     "Star4":null,
#     "No_of_Votes":40351.0,
#     "Gross":13780024.0,
#     "Director_Name":"Richard Lester",
#     "Genre":" Comedy, Music, Musical "
#   },
#   {
#     "ID":996,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BNGEwMTRmZTQtMDY4Ni00MTliLTk5ZmMtOWMxYWMyMTllMDg0L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Breakfast At Tiffany's",
#     "Released_Year":1961.0,
#     "Certificate":null,
#     "Runtime_Minutes":115,
#     "IMDB_Rating":7.6,
#     "Overview":"A young New York socialite becomes interested in a young man who has moved into her apartment building, but her past threatens to get in the way.",
#     "Meta_score":76.0,
#     "Star1":"Audrey Hepburn",
#     "Star2":"George Peppard",
#     "Star3":"Patricia Neal",
#     "Star4":null,
#     "No_of_Votes":166544.0,
#     "Gross":null,
#     "Director_Name":"Blake Edwards",
#     "Genre":"Comedy, Drama, Romance"
#   },
#   {
#     "ID":997,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BODk3YjdjZTItOGVhYi00Mjc2LTgzMDAtMThmYTVkNTBlMWVkXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Giant",
#     "Released_Year":1956.0,
#     "Certificate":"G",
#     "Runtime_Minutes":201,
#     "IMDB_Rating":7.6,
#     "Overview":"Sprawling epic covering the life of a Texas cattle rancher and his family and associates.",
#     "Meta_score":null,
#     "Star1":"Elizabeth Taylor",
#     "Star2":"Rock Hudson",
#     "Star3":"James Dean",
#     "Star4":"Carroll Baker",
#     "No_of_Votes":34075.0,
#     "Gross":null,
#     "Director_Name":"George Stevens",
#     "Genre":"Drama, Western"
#   },
#   {
#     "ID":998,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BM2U3YzkxNGMtYWE0YS00ODk0LTk1ZGEtNjk3ZTE0MTk4MzJjXkEyXkFqcGdeQXVyNDk0MDg4NDk@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"From Here To Eternity",
#     "Released_Year":1953.0,
#     "Certificate":"PASSED",
#     "Runtime_Minutes":null,
#     "IMDB_Rating":7.6,
#     "Overview":"In Hawaii in 1941, a private is cruelly punished for not boxing on his unit's team, while his captain's wife and second-in-command are falling in love.",
#     "Meta_score":85.0,
#     "Star1":"Burt Lancaster",
#     "Star2":"Montgomery Clift",
#     "Star3":"Deborah Kerr",
#     "Star4":"Donna Reed",
#     "No_of_Votes":43374.0,
#     "Gross":30500000.0,
#     "Director_Name":"Fred Zinnemann",
#     "Genre":"Drama, Romance, War"
#   },
#   {
#     "ID":999,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BZTBmMjUyMjItYTM4ZS00MjAwLWEyOGYtYjMyZTUxN2I3OTMxXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"Lifeboat",
#     "Released_Year":1944.0,
#     "Certificate":null,
#     "Runtime_Minutes":97,
#     "IMDB_Rating":7.6,
#     "Overview":"Several survivors of a torpedoed merchant ship in World War II find themselves in the same lifeboat with one of the crew members of the U-boat that sank their ship.",
#     "Meta_score":null,
#     "Star1":"Tallulah Bankhead",
#     "Star2":null,
#     "Star3":"Walter Slezak",
#     "Star4":"William Bendix",
#     "No_of_Votes":null,
#     "Gross":null,
#     "Director_Name":"Alfred Hitchcock",
#     "Genre":"Drama, War"
#   },
#   {
#     "ID":1000,
#     "Poster_Link":"https:\/\/m.media-amazon.com\/images\/M\/MV5BMTY5ODAzMTcwOF5BMl5BanBnXkFtZTcwMzYxNDYyNA@@._V1_UX67_CR0,0,67,98_AL_.jpg",
#     "Series_Title":"The 39 Steps",
#     "Released_Year":1935.0,
#     "Certificate":null,
#     "Runtime_Minutes":null,
#     "IMDB_Rating":7.6,
#     "Overview":"A man in London tries to help a counter-espionage Agent. But when the Agent is killed, and the man stands accused, he must go on the run to save himself and stop a spy ring which is trying to steal top secret information.",
#     "Meta_score":93.0,
#     "Star1":"Robert Donat",
#     "Star2":"Madeleine Carroll",
#     "Star3":"Lucie Mannheim",
#     "Star4":"Godfrey Tearle",
#     "No_of_Votes":51853.0,
#     "Gross":null,
#     "Director_Name":null,
#     "Genre":null
#   }
# ]

# %%
result = process_data_in_batches(
    df, 
    series_director_overview_country_tasks_list,
    batch_size=10
)

if result is not None:
    print("\n AI results:")
    print(result.head())
    print(f"\n Columns: {list(result.columns)}")
else:
    print("AI cleaning failed")
# Out:
# Processing 1000 rows in 100 batches of 10 rows each...
# Processing batch 1/100 (rows 1-10)
# Calling Gemini API for batch 1 (attempt 1/3)...
# Gemini API response received for batch 1
# Parsing AI response for batch 1...
# ✓ Batch 1 completed successfully
# Processing batch 2/100 (rows 11-20)
# Calling Gemini API for batch 2 (attempt 1/3)...
# Gemini API response received for batch 2
# Parsing AI response for batch 2...
# ✓ Batch 2 completed successfully
# Processing batch 3/100 (rows 21-30)
# Calling Gemini API for batch 3 (attempt 1/3)...
# Gemini API response received for batch 3
# Parsing AI response for batch 3...
# ✓ Batch 3 completed successfully
# Processing batch 4/100 (rows 31-40)
# Calling Gemini API for batch 4 (attempt 1/3)...
# Gemini API response received for batch 4
# Parsing AI response for batch 4...
# ✓ Batch 4 completed successfully
# Processing batch 5/100 (rows 41-50)
# Calling Gemini API for batch 5 (attempt 1/3)...
# Gemini API response received for batch 5
# Parsing AI response for batch 5...
# ✓ Batch 5 completed successfully
# Processing batch 6/100 (rows 51-60)
# Calling Gemini API for batch 6 (attempt 1/3)...
# Gemini API response received for batch 6
# Parsing AI response for batch 6...
# ✓ Batch 6 completed successfully
# Processing batch 7/100 (rows 61-70)
# Calling Gemini API for batch 7 (attempt 1/3)...
# Gemini API response received for batch 7
# Parsing AI response for batch 7...
# ✓ Batch 7 completed successfully
# Processing batch 8/100 (rows 71-80)
# Calling Gemini API for batch 8 (attempt 1/3)...
# Gemini API response received for batch 8
# Parsing AI response for batch 8...
# ✓ Batch 8 completed successfully
# Processing batch 9/100 (rows 81-90)
# Calling Gemini API for batch 9 (attempt 1/3)...
# Gemini API response received for batch 9
# Parsing AI response for batch 9...
# ✓ Batch 9 completed successfully
# Processing batch 10/100 (rows 91-100)
# Calling Gemini API for batch 10 (attempt 1/3)...
# Gemini API response received for batch 10
# Parsing AI response for batch 10...
# ✓ Batch 10 completed successfully
# Processing batch 11/100 (rows 101-110)
# Calling Gemini API for batch 11 (attempt 1/3)...
# Gemini API response received for batch 11
# Parsing AI response for batch 11...
# ✓ Batch 11 completed successfully
# Processing batch 12/100 (rows 111-120)
# Calling Gemini API for batch 12 (attempt 1/3)...
# Gemini API response received for batch 12
# Parsing AI response for batch 12...
# ✓ Batch 12 completed successfully
# Processing batch 13/100 (rows 121-130)
# Calling Gemini API for batch 13 (attempt 1/3)...
# Gemini API response received for batch 13
# Parsing AI response for batch 13...
# ✓ Batch 13 completed successfully
# Processing batch 14/100 (rows 131-140)
# Calling Gemini API for batch 14 (attempt 1/3)...
# Gemini API response received for batch 14
# Parsing AI response for batch 14...
# ✓ Batch 14 completed successfully
# Processing batch 15/100 (rows 141-150)
# Calling Gemini API for batch 15 (attempt 1/3)...
# Gemini API response received for batch 15
# Parsing AI response for batch 15...
# ✓ Batch 15 completed successfully
# Processing batch 16/100 (rows 151-160)
# Calling Gemini API for batch 16 (attempt 1/3)...
# Gemini API response received for batch 16
# Parsing AI response for batch 16...
# ✓ Batch 16 completed successfully
# Processing batch 17/100 (rows 161-170)
# Calling Gemini API for batch 17 (attempt 1/3)...
# Gemini API response received for batch 17
# Parsing AI response for batch 17...
# ✓ Batch 17 completed successfully
# Processing batch 18/100 (rows 171-180)
# Calling Gemini API for batch 18 (attempt 1/3)...
# Gemini API response received for batch 18
# Parsing AI response for batch 18...
# ✓ Batch 18 completed successfully
# Processing batch 19/100 (rows 181-190)
# Calling Gemini API for batch 19 (attempt 1/3)...
# Gemini API response received for batch 19
# Parsing AI response for batch 19...
# ✓ Batch 19 completed successfully
# Processing batch 20/100 (rows 191-200)
# Calling Gemini API for batch 20 (attempt 1/3)...
# Gemini API response received for batch 20
# Parsing AI response for batch 20...
# ✓ Batch 20 completed successfully
# Processing batch 21/100 (rows 201-210)
# Calling Gemini API for batch 21 (attempt 1/3)...
# Gemini API response received for batch 21
# Parsing AI response for batch 21...
# ✓ Batch 21 completed successfully
# Processing batch 22/100 (rows 211-220)
# Calling Gemini API for batch 22 (attempt 1/3)...
# Gemini API response received for batch 22
# Parsing AI response for batch 22...
# ✓ Batch 22 completed successfully
# Processing batch 23/100 (rows 221-230)
# Calling Gemini API for batch 23 (attempt 1/3)...
# Gemini API response received for batch 23
# Parsing AI response for batch 23...
# ✓ Batch 23 completed successfully
# Processing batch 24/100 (rows 231-240)
# Calling Gemini API for batch 24 (attempt 1/3)...
# Gemini API response received for batch 24
# Parsing AI response for batch 24...
# ✓ Batch 24 completed successfully
# Processing batch 25/100 (rows 241-250)
# Calling Gemini API for batch 25 (attempt 1/3)...
# Gemini API response received for batch 25
# Parsing AI response for batch 25...
# ✓ Batch 25 completed successfully
# Processing batch 26/100 (rows 251-260)
# Calling Gemini API for batch 26 (attempt 1/3)...
# Gemini API response received for batch 26
# Parsing AI response for batch 26...
# ✓ Batch 26 completed successfully
# Processing batch 27/100 (rows 261-270)
# Calling Gemini API for batch 27 (attempt 1/3)...
# Gemini API response received for batch 27
# Parsing AI response for batch 27...
# ✓ Batch 27 completed successfully
# Processing batch 28/100 (rows 271-280)
# Calling Gemini API for batch 28 (attempt 1/3)...
# Gemini API response received for batch 28
# Parsing AI response for batch 28...
# ✓ Batch 28 completed successfully
# Processing batch 29/100 (rows 281-290)
# Calling Gemini API for batch 29 (attempt 1/3)...
# Gemini API response received for batch 29
# Parsing AI response for batch 29...
# ✓ Batch 29 completed successfully
# Processing batch 30/100 (rows 291-300)
# Calling Gemini API for batch 30 (attempt 1/3)...
# Gemini API response received for batch 30
# Parsing AI response for batch 30...
# ✓ Batch 30 completed successfully
# Processing batch 31/100 (rows 301-310)
# Calling Gemini API for batch 31 (attempt 1/3)...
# Gemini API response received for batch 31
# Parsing AI response for batch 31...
# ✓ Batch 31 completed successfully
# Processing batch 32/100 (rows 311-320)
# Calling Gemini API for batch 32 (attempt 1/3)...
# Gemini API response received for batch 32
# Parsing AI response for batch 32...
# ✓ Batch 32 completed successfully
# Processing batch 33/100 (rows 321-330)
# Calling Gemini API for batch 33 (attempt 1/3)...
# Gemini API response received for batch 33
# Parsing AI response for batch 33...
# ✓ Batch 33 completed successfully
# Processing batch 34/100 (rows 331-340)
# Calling Gemini API for batch 34 (attempt 1/3)...
# Gemini API response received for batch 34
# Parsing AI response for batch 34...
# ✓ Batch 34 completed successfully
# Processing batch 35/100 (rows 341-350)
# Calling Gemini API for batch 35 (attempt 1/3)...
# Gemini API response received for batch 35
# Parsing AI response for batch 35...
# ✓ Batch 35 completed successfully
# Processing batch 36/100 (rows 351-360)
# Calling Gemini API for batch 36 (attempt 1/3)...
# Gemini API response received for batch 36
# Parsing AI response for batch 36...
# ✓ Batch 36 completed successfully
# Processing batch 37/100 (rows 361-370)
# Calling Gemini API for batch 37 (attempt 1/3)...
# Gemini API response received for batch 37
# Parsing AI response for batch 37...
# ✓ Batch 37 completed successfully
# Processing batch 38/100 (rows 371-380)
# Calling Gemini API for batch 38 (attempt 1/3)...
# Gemini API response received for batch 38
# Parsing AI response for batch 38...
# ✓ Batch 38 completed successfully
# Processing batch 39/100 (rows 381-390)
# Calling Gemini API for batch 39 (attempt 1/3)...
# Gemini API response received for batch 39
# Parsing AI response for batch 39...
# ✓ Batch 39 completed successfully
# Processing batch 40/100 (rows 391-400)
# Calling Gemini API for batch 40 (attempt 1/3)...
# Gemini API response received for batch 40
# Parsing AI response for batch 40...
# ✓ Batch 40 completed successfully
# Processing batch 41/100 (rows 401-410)
# Calling Gemini API for batch 41 (attempt 1/3)...
# Gemini API response received for batch 41
# Parsing AI response for batch 41...
# ✓ Batch 41 completed successfully
# Processing batch 42/100 (rows 411-420)
# Calling Gemini API for batch 42 (attempt 1/3)...
# Gemini API response received for batch 42
# Parsing AI response for batch 42...
# ✓ Batch 42 completed successfully
# Processing batch 43/100 (rows 421-430)
# Calling Gemini API for batch 43 (attempt 1/3)...
# Gemini API response received for batch 43
# Parsing AI response for batch 43...
# ✓ Batch 43 completed successfully
# Processing batch 44/100 (rows 431-440)
# Calling Gemini API for batch 44 (attempt 1/3)...
# Gemini API response received for batch 44
# Parsing AI response for batch 44...
# ✓ Batch 44 completed successfully
# Processing batch 45/100 (rows 441-450)
# Calling Gemini API for batch 45 (attempt 1/3)...
# Gemini API response received for batch 45
# Parsing AI response for batch 45...
# ✓ Batch 45 completed successfully
# Processing batch 46/100 (rows 451-460)
# Calling Gemini API for batch 46 (attempt 1/3)...
# Gemini API response received for batch 46
# Parsing AI response for batch 46...
# ✓ Batch 46 completed successfully
# Processing batch 47/100 (rows 461-470)
# Calling Gemini API for batch 47 (attempt 1/3)...
# Gemini API response received for batch 47
# Parsing AI response for batch 47...
# ✓ Batch 47 completed successfully
# Processing batch 48/100 (rows 471-480)
# Calling Gemini API for batch 48 (attempt 1/3)...
# Gemini API response received for batch 48
# Parsing AI response for batch 48...
# ✓ Batch 48 completed successfully
# Processing batch 49/100 (rows 481-490)
# Calling Gemini API for batch 49 (attempt 1/3)...
# Gemini API response received for batch 49
# Parsing AI response for batch 49...
# ✓ Batch 49 completed successfully
# Processing batch 50/100 (rows 491-500)
# Calling Gemini API for batch 50 (attempt 1/3)...
# Gemini API response received for batch 50
# Parsing AI response for batch 50...
# ✓ Batch 50 completed successfully
# Processing batch 51/100 (rows 501-510)
# Calling Gemini API for batch 51 (attempt 1/3)...
# Gemini API response received for batch 51
# Parsing AI response for batch 51...
# ✓ Batch 51 completed successfully
# Processing batch 52/100 (rows 511-520)
# Calling Gemini API for batch 52 (attempt 1/3)...
# Gemini API response received for batch 52
# Parsing AI response for batch 52...
# ✓ Batch 52 completed successfully
# Processing batch 53/100 (rows 521-530)
# Calling Gemini API for batch 53 (attempt 1/3)...
# Gemini API response received for batch 53
# Parsing AI response for batch 53...
# ✓ Batch 53 completed successfully
# Processing batch 54/100 (rows 531-540)
# Calling Gemini API for batch 54 (attempt 1/3)...
# Gemini API response received for batch 54
# Parsing AI response for batch 54...
# ✓ Batch 54 completed successfully
# Processing batch 55/100 (rows 541-550)
# Calling Gemini API for batch 55 (attempt 1/3)...
# Gemini API response received for batch 55
# Parsing AI response for batch 55...
# ✓ Batch 55 completed successfully
# Processing batch 56/100 (rows 551-560)
# Calling Gemini API for batch 56 (attempt 1/3)...
# Gemini API response received for batch 56
# Parsing AI response for batch 56...
# ✓ Batch 56 completed successfully
# Processing batch 57/100 (rows 561-570)
# Calling Gemini API for batch 57 (attempt 1/3)...
# Gemini API response received for batch 57
# Parsing AI response for batch 57...
# ✓ Batch 57 completed successfully
# Processing batch 58/100 (rows 571-580)
# Calling Gemini API for batch 58 (attempt 1/3)...
# Gemini API response received for batch 58
# Parsing AI response for batch 58...
# ✓ Batch 58 completed successfully
# Processing batch 59/100 (rows 581-590)
# Calling Gemini API for batch 59 (attempt 1/3)...
# Gemini API response received for batch 59
# Parsing AI response for batch 59...
# ✓ Batch 59 completed successfully
# Processing batch 60/100 (rows 591-600)
# Calling Gemini API for batch 60 (attempt 1/3)...
# Gemini API response received for batch 60
# Parsing AI response for batch 60...
# ✓ Batch 60 completed successfully
# Processing batch 61/100 (rows 601-610)
# Calling Gemini API for batch 61 (attempt 1/3)...
# Gemini API response received for batch 61
# Parsing AI response for batch 61...
# ✓ Batch 61 completed successfully
# Processing batch 62/100 (rows 611-620)
# Calling Gemini API for batch 62 (attempt 1/3)...
# Gemini API response received for batch 62
# Parsing AI response for batch 62...
# ✓ Batch 62 completed successfully
# Processing batch 63/100 (rows 621-630)
# Calling Gemini API for batch 63 (attempt 1/3)...
# Gemini API response received for batch 63
# Parsing AI response for batch 63...
# ✓ Batch 63 completed successfully
# Processing batch 64/100 (rows 631-640)
# Calling Gemini API for batch 64 (attempt 1/3)...
# Gemini API response received for batch 64
# Parsing AI response for batch 64...
# ✓ Batch 64 completed successfully
# Processing batch 65/100 (rows 641-650)
# Calling Gemini API for batch 65 (attempt 1/3)...
# Gemini API response received for batch 65
# Parsing AI response for batch 65...
# ✓ Batch 65 completed successfully
# Processing batch 66/100 (rows 651-660)
# Calling Gemini API for batch 66 (attempt 1/3)...
# Gemini API response received for batch 66
# Parsing AI response for batch 66...
# ✓ Batch 66 completed successfully
# Processing batch 67/100 (rows 661-670)
# Calling Gemini API for batch 67 (attempt 1/3)...
# Gemini API response received for batch 67
# Parsing AI response for batch 67...
# ✓ Batch 67 completed successfully
# Processing batch 68/100 (rows 671-680)
# Calling Gemini API for batch 68 (attempt 1/3)...
# Gemini API response received for batch 68
# Parsing AI response for batch 68...
# ✓ Batch 68 completed successfully
# Processing batch 69/100 (rows 681-690)
# Calling Gemini API for batch 69 (attempt 1/3)...
# Gemini API response received for batch 69
# Parsing AI response for batch 69...
# ✓ Batch 69 completed successfully
# Processing batch 70/100 (rows 691-700)
# Calling Gemini API for batch 70 (attempt 1/3)...
# Gemini API response received for batch 70
# Parsing AI response for batch 70...
# ✓ Batch 70 completed successfully
# Processing batch 71/100 (rows 701-710)
# Calling Gemini API for batch 71 (attempt 1/3)...
# Gemini API response received for batch 71
# Parsing AI response for batch 71...
# ✓ Batch 71 completed successfully
# Processing batch 72/100 (rows 711-720)
# Calling Gemini API for batch 72 (attempt 1/3)...
# Gemini API response received for batch 72
# Parsing AI response for batch 72...
# ✓ Batch 72 completed successfully
# Processing batch 73/100 (rows 721-730)
# Calling Gemini API for batch 73 (attempt 1/3)...
# Gemini API response received for batch 73
# Parsing AI response for batch 73...
# ✓ Batch 73 completed successfully
# Processing batch 74/100 (rows 731-740)
# Calling Gemini API for batch 74 (attempt 1/3)...
# Gemini API response received for batch 74
# Parsing AI response for batch 74...
# ✓ Batch 74 completed successfully
# Processing batch 75/100 (rows 741-750)
# Calling Gemini API for batch 75 (attempt 1/3)...
# Gemini API response received for batch 75
# Parsing AI response for batch 75...
# ✓ Batch 75 completed successfully
# Processing batch 76/100 (rows 751-760)
# Calling Gemini API for batch 76 (attempt 1/3)...
# Gemini API response received for batch 76
# Parsing AI response for batch 76...
# ✓ Batch 76 completed successfully
# Processing batch 77/100 (rows 761-770)
# Calling Gemini API for batch 77 (attempt 1/3)...
# Gemini API response received for batch 77
# Parsing AI response for batch 77...
# ✓ Batch 77 completed successfully
# Processing batch 78/100 (rows 771-780)
# Calling Gemini API for batch 78 (attempt 1/3)...
# Gemini API response received for batch 78
# Parsing AI response for batch 78...
# ✓ Batch 78 completed successfully
# Processing batch 79/100 (rows 781-790)
# Calling Gemini API for batch 79 (attempt 1/3)...
# Gemini API response received for batch 79
# Parsing AI response for batch 79...
# ✓ Batch 79 completed successfully
# Processing batch 80/100 (rows 791-800)
# Calling Gemini API for batch 80 (attempt 1/3)...
# Gemini API response received for batch 80
# Parsing AI response for batch 80...
# ✓ Batch 80 completed successfully
# Processing batch 81/100 (rows 801-810)
# Calling Gemini API for batch 81 (attempt 1/3)...
# Gemini API response received for batch 81
# Parsing AI response for batch 81...
# ✓ Batch 81 completed successfully
# Processing batch 82/100 (rows 811-820)
# Calling Gemini API for batch 82 (attempt 1/3)...
# Gemini API response received for batch 82
# Parsing AI response for batch 82...
# ✓ Batch 82 completed successfully
# Processing batch 83/100 (rows 821-830)
# Calling Gemini API for batch 83 (attempt 1/3)...
# Gemini API response received for batch 83
# Parsing AI response for batch 83...
# ✓ Batch 83 completed successfully
# Processing batch 84/100 (rows 831-840)
# Calling Gemini API for batch 84 (attempt 1/3)...
# Gemini API response received for batch 84
# Parsing AI response for batch 84...
# ✓ Batch 84 completed successfully
# Processing batch 85/100 (rows 841-850)
# Calling Gemini API for batch 85 (attempt 1/3)...
# Gemini API response received for batch 85
# Parsing AI response for batch 85...
# ✓ Batch 85 completed successfully
# Processing batch 86/100 (rows 851-860)
# Calling Gemini API for batch 86 (attempt 1/3)...
# Gemini API response received for batch 86
# Parsing AI response for batch 86...
# ✓ Batch 86 completed successfully
# Processing batch 87/100 (rows 861-870)
# Calling Gemini API for batch 87 (attempt 1/3)...
# Gemini API response received for batch 87
# Parsing AI response for batch 87...
# ✓ Batch 87 completed successfully
# Processing batch 88/100 (rows 871-880)
# Calling Gemini API for batch 88 (attempt 1/3)...
# Gemini API response received for batch 88
# Parsing AI response for batch 88...
# ✓ Batch 88 completed successfully
# Processing batch 89/100 (rows 881-890)
# Calling Gemini API for batch 89 (attempt 1/3)...
# Gemini API response received for batch 89
# Parsing AI response for batch 89...
# ✓ Batch 89 completed successfully
# Processing batch 90/100 (rows 891-900)
# Calling Gemini API for batch 90 (attempt 1/3)...
# Gemini API response received for batch 90
# Parsing AI response for batch 90...
# ✓ Batch 90 completed successfully
# Processing batch 91/100 (rows 901-910)
# Calling Gemini API for batch 91 (attempt 1/3)...
# Gemini API response received for batch 91
# Parsing AI response for batch 91...
# ✓ Batch 91 completed successfully
# Processing batch 92/100 (rows 911-920)
# Calling Gemini API for batch 92 (attempt 1/3)...
# Gemini API response received for batch 92
# Parsing AI response for batch 92...
# ✓ Batch 92 completed successfully
# Processing batch 93/100 (rows 921-930)
# Calling Gemini API for batch 93 (attempt 1/3)...
# Gemini API response received for batch 93
# Parsing AI response for batch 93...
# ✓ Batch 93 completed successfully
# Processing batch 94/100 (rows 931-940)
# Calling Gemini API for batch 94 (attempt 1/3)...
# Gemini API response received for batch 94
# Parsing AI response for batch 94...
# ✓ Batch 94 completed successfully
# Processing batch 95/100 (rows 941-950)
# Calling Gemini API for batch 95 (attempt 1/3)...
# Gemini API response received for batch 95
# Parsing AI response for batch 95...
# ✓ Batch 95 completed successfully
# Processing batch 96/100 (rows 951-960)
# Calling Gemini API for batch 96 (attempt 1/3)...
# Gemini API response received for batch 96
# Parsing AI response for batch 96...
# ✓ Batch 96 completed successfully
# Processing batch 97/100 (rows 961-970)
# Calling Gemini API for batch 97 (attempt 1/3)...
# Gemini API response received for batch 97
# Parsing AI response for batch 97...
# ✓ Batch 97 completed successfully
# Processing batch 98/100 (rows 971-980)
# Calling Gemini API for batch 98 (attempt 1/3)...
# Gemini API response received for batch 98
# Parsing AI response for batch 98...
# ✓ Batch 98 completed successfully
# Processing batch 99/100 (rows 981-990)
# Calling Gemini API for batch 99 (attempt 1/3)...
# Gemini API response received for batch 99
# Parsing AI response for batch 99...
# ✓ Batch 99 completed successfully
# Processing batch 100/100 (rows 991-1000)
# Calling Gemini API for batch 100 (attempt 1/3)...
# Gemini API response received for batch 100
# Parsing AI response for batch 100...
# ✓ Batch 100 completed successfully
# ✓ All batches completed. Final dataset: 1000 rows
#
#  AI results:
#    ID                                        Poster_Link  \
# 0   1  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   2  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   3  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   4  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   5  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate Runtime_Minutes  \
# 0  The Shawshank Redemption        1994.0           R             142
# 1             The Godfather        1972.0           A             175
# 2           The Dark Knight        2008.0          UA             152
# 3    The Godfather: Part II        1974.0           A             202
# 4              12 Angry Men        1957.0           U              96
#
#   IMDB_Rating                                           Overview Meta_score  \
# 0         9.3  Two imprisoned men bond over a number of years...       80.0
# 1         9.2  An organized crime dynasty's aging patriarch t...      100.0
# 2         9.0  When the menace known as the Joker wreaks havo...       84.0
# 3     Unknown                                            Unknown       90.0
# 4         9.0  A jury holdout attempts to prevent a miscarria...       96.0
#
#             Star1         Star2          Star3           Star4 No_of_Votes  \
# 0     Tim Robbins       Unknown     Bob Gunton  William Sadler   2343110.0
# 1   Marlon Brando       Unknown     James Caan    Diane Keaton   1620367.0
# 2  Christian Bale  Heath Ledger  Aaron Eckhart   Michael Caine   2303232.0
# 3       Al Pacino       Unknown  Robert Duvall    Diane Keaton     Unknown
# 4     Henry Fonda   Lee J. Cobb  Martin Balsam         Unknown    689845.0
#
#          Gross         Director_Name                   Genre Country_Origin
# 0   28341469.0        Frank Darabont                   Drama            USA
# 1      Unknown  Francis Ford Coppola            Crime, Drama            USA
# 2  534858444.0     Christopher Nolan   Action, Crime, Drama             USA
# 3      Unknown  Francis Ford Coppola           Crime, Drama             USA
# 4    4360000.0          Sidney Lumet            Crime, Drama            USA
#
#  Columns: ['ID', 'Poster_Link', 'Series_Title', 'Released_Year', 'Certificate', 'Runtime_Minutes', 'IMDB_Rating', 'Overview', 'Meta_score', 'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross', 'Director_Name', 'Genre', 'Country_Origin']

# %%
result.head()
# Out:
#    ID                                        Poster_Link  \
# 0   1  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   2  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   3  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   4  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   5  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate Runtime_Minutes  \
# 0  The Shawshank Redemption        1994.0           R             142
# 1             The Godfather        1972.0           A             175
# 2           The Dark Knight        2008.0          UA             152
# 3    The Godfather: Part II        1974.0           A             202
# 4              12 Angry Men        1957.0           U              96
#
#   IMDB_Rating                                           Overview Meta_score  \
# 0         9.3  Two imprisoned men bond over a number of years...       80.0
# 1         9.2  An organized crime dynasty's aging patriarch t...      100.0
# 2         9.0  When the menace known as the Joker wreaks havo...       84.0
# 3     Unknown                                            Unknown       90.0
# 4         9.0  A jury holdout attempts to prevent a miscarria...       96.0
#
#             Star1         Star2          Star3           Star4 No_of_Votes  \
# 0     Tim Robbins       Unknown     Bob Gunton  William Sadler   2343110.0
# 1   Marlon Brando       Unknown     James Caan    Diane Keaton   1620367.0
# 2  Christian Bale  Heath Ledger  Aaron Eckhart   Michael Caine   2303232.0
# 3       Al Pacino       Unknown  Robert Duvall    Diane Keaton     Unknown
# 4     Henry Fonda   Lee J. Cobb  Martin Balsam         Unknown    689845.0
#
#          Gross         Director_Name                   Genre Country_Origin
# 0   28341469.0        Frank Darabont                   Drama            USA
# 1      Unknown  Francis Ford Coppola            Crime, Drama            USA
# 2  534858444.0     Christopher Nolan   Action, Crime, Drama             USA
# 3      Unknown  Francis Ford Coppola           Crime, Drama             USA
# 4    4360000.0          Sidney Lumet            Crime, Drama            USA

# %% [markdown]
# ## 6. Export The Result

# %%
result.to_csv('Datasets/02_Cleaned/Cleaned_imdb_top_1000_v1.csv', index=False)
